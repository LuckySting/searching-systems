# %%
# imports
from natasha import (
    Segmenter,
    MorphVocab,
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    PER,
    LOC,
    ORG,
    NamesExtractor,
    DatesExtractor,
    AddrExtractor,
    Doc
)
from natasha.grammars.date import YEAR

from yargy import Parser, rule, or_, and_
from yargy.predicates import gram, dictionary, gte, lte, type, eq, is_capitalized, true, custom
from yargy.pipelines import morph_pipeline
from yargy.interpretation import fact

# %%
with open('patrologia_latina.txt') as file:
    text = file.read()
text
# Out:
# 'Patrologia Latina (Латинская патрология), или Patrologiae Cursus Completus — собрание сочинений латиноязычных христианских авторов, включающее 217 огромных томов, первая часть «Полного курса патрологии» (Patrologiæ Cursus Completus), вторая часть — Patrologia Græca. Изданы аббатом Минем в 1844—1855 годах, в 1862—1865 опубликованы указатели. Охватывает период примерно в тысячу лет — с конца II по начало XIII века. Первоначально Минь планировал опубликовать все сочинения вплоть до эпохи Возрождения, но объём издания оказался слишком велик. Издание отличает полнота жанров: включены богословские труды, агиография, поэзия, историческая и научная литература, переводы с греческого, переписка, материалы соборов, различная документация. Корпус представляет собой по сути огромную перепечатку ранее опубликованных изданий и не имеет самостоятельного текстологического значения[1]. Значительное число произведений с тех пор не переиздавалось, и издание продолжает использоваться медиевистами, хотя в настоящее время устарело и не отвечает современным научным стандартам. В издании есть и серьёзные недостатки. Хронологический принцип выдержан не полностью, труды некоторых авторов помещены сразу в несколько томов, включены и заведомо апокрифические сочинения.\n1-2\tТертуллиан\n3\t«Мученичество святых Перпетуи и Фелицитаты»; Минуций Феликс; «Книга происхождения от Адама»; авторы писем Киприану (Максим, Сидоний, Махарий); Корнелий (папа римский); Новациан; Луций I (папа римский); Стефан I (папа римский); акты Карфагенского собора; анонимный «Трактат к еретикам новацианам»; Морцелл\n4\tКиприан Карфагенский\n5\tСикст II (папа римский); Дионисий Александрийский; Феликс I (папа римский); Евтихиан (папа римский); Гай (папа римский); Коммодиан; анонимная «Песнь против язычников»; Викторин из Петтау; Магнет; Арнобий\n6\tМарцеллин (папа римский); Евсевий (папа римский); Мильтиад (папа римский); анонимная «Песнь во славу Господа»; Цельс; Лактанций\n7\tЛактанций\n8\tКонстантин I Великий; Панегирики (Назарий, Евмений и аноним); Итинерарий из Бурдигалы в Иерусалим; Сильвестр I (папа римский); Марк (папа римский); Юлий I (папа римский); Викторин Африканец; Осий Кордовский; Либерий (папа римский); Потамий (епископ)\n9-10\tИларий из Пуатье\n11\tЗенон Веронский; Оптат Милевитанский\n12\tЕвсевий Верчелльский; Фирмик Матерн; Филастрий\n13\tСириций (папа римский); Фаустин и Марцеллин; Дамасий I (папа римский); Викторий Аквитанский; Феодосий I Великий; Вигилий (епископ); древние тексты об арианской доктрине; Фурий Дионисий Филокал; Полемей Сильвий; Люцифер Калаританский; Пациан; Юлий Гилариан\n14-17\tАмвросий Медиоланский\n18\tМартин Турский; Тихоний Африканский; Нованций; Аврелий Симмах; Максим Грамматик; Клавдий Мамертин (панегирист); Публий Виктор; Ульфила\n19\tЮвенк; Оптациан; Целий Седулий; Север (ритор); Фальтония Проба; Авзоний\n20\tФебадий (епископ Аженский); Павлин Медиоланский; Анастасий II (папа римский); Сульпиций Север; Кромаций (епископ Аквилейский); Иннокентий I (папа римский); Зосима (папа римский); Бонифаций I (папа римский); Гауденций (епископ Брешии); Аврелий Карфагенский; Бахиарий; Закхей[2]; Евагрий Понтийский (перевод)\n21\tРуфин Аквилейский; Пелагий Британец\n22-30\tИероним Стридонский (т. 27: «Хроника» с продолжением Проспера Аквитанского, в т.30 включены также тексты папы Мартина V)\n31\tФлавий Луций Декстер[3]; Орозий; Лепорий\n32-47\tАврелий Августин; также, помимо его сочинений, в т.41 помещены: пресвитер Авит; Лукиан (пресвитер Кафар Гамалы); Анастасий Библиотекарь; Север с Менорки; в т.42: Кводвультдей; Секунд (манихей); Орозий; Алкуин; т.44: также одно письмо Проспера Аквитанского; т.45: ряд текстов Проспера Аквитанского; т.46: Поссидий (епископ Каламы)\n48\tМарий Меркатор\n49\tИоанн Кассиан\n50\tИоанн Кассиан; Пахомий Великий; Вигилий (диакон); Фастидий; Целестин I (папа римский); Антонин Гонорат (епископ Константины); Сикст III (папа римский); Викентий Леринский; Евхерий Лионский; Иларий Арелатский)\n51\tПроспер Аквитанский; Идаций (е ...

# %%
# text filtering
text = text.replace('\t', ' ')
text
# Out:
# 'Patrologia Latina (Латинская патрология), или Patrologiae Cursus Completus — собрание сочинений латиноязычных христианских авторов, включающее 217 огромных томов, первая часть «Полного курса патрологии» (Patrologiæ Cursus Completus), вторая часть — Patrologia Græca. Изданы аббатом Минем в 1844—1855 годах, в 1862—1865 опубликованы указатели. Охватывает период примерно в тысячу лет — с конца II по начало XIII века. Первоначально Минь планировал опубликовать все сочинения вплоть до эпохи Возрождения, но объём издания оказался слишком велик. Издание отличает полнота жанров: включены богословские труды, агиография, поэзия, историческая и научная литература, переводы с греческого, переписка, материалы соборов, различная документация. Корпус представляет собой по сути огромную перепечатку ранее опубликованных изданий и не имеет самостоятельного текстологического значения[1]. Значительное число произведений с тех пор не переиздавалось, и издание продолжает использоваться медиевистами, хотя в настоящее время устарело и не отвечает современным научным стандартам. В издании есть и серьёзные недостатки. Хронологический принцип выдержан не полностью, труды некоторых авторов помещены сразу в несколько томов, включены и заведомо апокрифические сочинения.\n1-2 Тертуллиан\n3 «Мученичество святых Перпетуи и Фелицитаты»; Минуций Феликс; «Книга происхождения от Адама»; авторы писем Киприану (Максим, Сидоний, Махарий); Корнелий (папа римский); Новациан; Луций I (папа римский); Стефан I (папа римский); акты Карфагенского собора; анонимный «Трактат к еретикам новацианам»; Морцелл\n4 Киприан Карфагенский\n5 Сикст II (папа римский); Дионисий Александрийский; Феликс I (папа римский); Евтихиан (папа римский); Гай (папа римский); Коммодиан; анонимная «Песнь против язычников»; Викторин из Петтау; Магнет; Арнобий\n6 Марцеллин (папа римский); Евсевий (папа римский); Мильтиад (папа римский); анонимная «Песнь во славу Господа»; Цельс; Лактанций\n7 Лактанций\n8 Константин I Великий; Панегирики (Назарий, Евмений и аноним); Итинерарий из Бурдигалы в Иерусалим; Сильвестр I (папа римский); Марк (папа римский); Юлий I (папа римский); Викторин Африканец; Осий Кордовский; Либерий (папа римский); Потамий (епископ)\n9-10 Иларий из Пуатье\n11 Зенон Веронский; Оптат Милевитанский\n12 Евсевий Верчелльский; Фирмик Матерн; Филастрий\n13 Сириций (папа римский); Фаустин и Марцеллин; Дамасий I (папа римский); Викторий Аквитанский; Феодосий I Великий; Вигилий (епископ); древние тексты об арианской доктрине; Фурий Дионисий Филокал; Полемей Сильвий; Люцифер Калаританский; Пациан; Юлий Гилариан\n14-17 Амвросий Медиоланский\n18 Мартин Турский; Тихоний Африканский; Нованций; Аврелий Симмах; Максим Грамматик; Клавдий Мамертин (панегирист); Публий Виктор; Ульфила\n19 Ювенк; Оптациан; Целий Седулий; Север (ритор); Фальтония Проба; Авзоний\n20 Фебадий (епископ Аженский); Павлин Медиоланский; Анастасий II (папа римский); Сульпиций Север; Кромаций (епископ Аквилейский); Иннокентий I (папа римский); Зосима (папа римский); Бонифаций I (папа римский); Гауденций (епископ Брешии); Аврелий Карфагенский; Бахиарий; Закхей[2]; Евагрий Понтийский (перевод)\n21 Руфин Аквилейский; Пелагий Британец\n22-30 Иероним Стридонский (т. 27: «Хроника» с продолжением Проспера Аквитанского, в т.30 включены также тексты папы Мартина V)\n31 Флавий Луций Декстер[3]; Орозий; Лепорий\n32-47 Аврелий Августин; также, помимо его сочинений, в т.41 помещены: пресвитер Авит; Лукиан (пресвитер Кафар Гамалы); Анастасий Библиотекарь; Север с Менорки; в т.42: Кводвультдей; Секунд (манихей); Орозий; Алкуин; т.44: также одно письмо Проспера Аквитанского; т.45: ряд текстов Проспера Аквитанского; т.46: Поссидий (епископ Каламы)\n48 Марий Меркатор\n49 Иоанн Кассиан\n50 Иоанн Кассиан; Пахомий Великий; Вигилий (диакон); Фастидий; Целестин I (папа римский); Антонин Гонорат (епископ Константины); Сикст III (папа римский); Викентий Леринский; Евхерий Лионский; Иларий Арелатский)\n51 Проспер Аквитанский; Идаций (епископ Шавешский); Марц ...

# %%
#определяем необходимые функции для работы с текстом
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb) # морфологический разбор слова
syntax_parser = NewsSyntaxParser(emb) # анализ синтаксиса 
ner_tagger = NewsNERTagger(emb) #извлечение именованных сущностей

names_extractor = NamesExtractor(morph_vocab)
dates_extractor = DatesExtractor(morph_vocab)
addr_extractor = AddrExtractor(morph_vocab)

# %%
doc = Doc(text)
doc.segment(segmenter)
doc.tag_morph(morph_tagger)
doc.parse_syntax(syntax_parser)
doc.tag_ner(ner_tagger)

# %%
persons = []
dates = []
organisations = []
for span in doc.spans:
    span.normalize(morph_vocab)
    if span.type == PER:
        span.extract_fact(names_extractor)
        if span.fact:
            persons.append(span.fact.as_dict)
    if span.type == ORG:
        organisations.append(span.normal)

for date_match in dates_extractor(text):
    dates.append(dates.append(date_match.fact))

# %%
# Persons
persons
# Out:
# [{'first': 'Минь'},
#  {'first': 'Минь'},
#  {'first': 'Тертуллиан'},
#  {'first': 'Феликс', 'last': 'Минуций'},
#  {'first': 'Киприану'},
#  {'first': 'Максим'},
#  {'first': 'Сидоний'},
#  {'first': 'Махарий'},
#  {'first': 'Корнелий'},
#  {'first': 'Луций', 'last': 'I'},
#  {'first': 'Стефан', 'last': 'I'},
#  {'first': 'Киприан', 'last': 'Карфагенский'},
#  {'first': 'Дионисий', 'last': 'Александрийский'},
#  {'first': 'Феликс', 'last': 'I'},
#  {'first': 'Евтихиан'},
#  {'first': 'Гай'},
#  {'first': 'Коммодиан'},
#  {'first': 'Викторин'},
#  {'first': 'Магнет'},
#  {'first': 'Марцеллин'},
#  {'first': 'Евсевий'},
#  {'first': 'Мильтиад'},
#  {'first': 'Константин', 'last': 'I'},
#  {'first': 'Евмений'},
#  {'first': 'Сильвестр', 'last': 'I'},
#  {'first': 'Марк'},
#  {'first': 'Юлий', 'last': 'I'},
#  {'first': 'Викторин', 'last': 'Африканец'},
#  {'first': 'Осий', 'last': 'Кордовский'},
#  {'first': 'Либерий'},
#  {'first': 'Потамий'},
#  {'first': 'Иларий'},
#  {'first': 'Зенон', 'last': 'Веронский'},
#  {'last': 'Милевитанский'},
#  {'first': 'Евсевий', 'last': 'Верчелльский'},
#  {'first': 'Фирмик', 'last': 'Матерн'},
#  {'first': 'Фаустин'},
#  {'first': 'Марцеллин'},
#  {'first': 'Дамасий', 'last': 'I'},
#  {'first': 'Викторий', 'last': 'Аквитанский'},
#  {'first': 'Феодосий', 'last': 'I'},
#  {'first': 'Вигилий'},
#  {'first': 'Дионисий', 'last': 'Фурий'},
#  {'first': 'Полемей', 'last': 'Сильвий'},
#  {'first': 'Люцифер', 'last': 'Калаританский'},
#  {'first': 'Юлий', 'last': 'Гилариан'},
#  {'first': 'Амвросий', 'last': 'Медиоланский'},
#  {'first': 'Мартин', 'last': 'Турский'},
#  {'first': 'Аврелий', 'last': 'Симмах'},
#  {'first': 'Максим', 'last': 'Грамматик'},
#  {'first': 'Клавдий', 'last': 'Мамертин'},
#  {'first': 'Публий', 'last': 'Виктор'},
#  {'first': 'Ульфил'},
#  {'first': 'Целий', 'last': 'Седулий'},
#  {'first': 'Фебадий'},
#  {'first': 'Павлин', 'last': 'Медиоланский'},
#  {'first': 'Анастасий', 'last': 'II'},
#  {'last': 'Север'},
#  {'first': 'Иннокентий', 'last': 'I'},
#  {'first': 'Зосима'},
#  {'first': 'Бонифаций', 'last': 'I'},
#  {'first': 'Аврелий', 'last': 'Карфагенский'},
#  {'first': 'Бахиарий'},
#  {'first': 'Закхей'},
#  {'first': 'Евагрий', 'last': 'Понтийский'},
#  {'first': 'Руфин', 'last': 'Аквилейский'},
#  {'first': 'Пелагий', 'last': 'Британец'},
#  {'first': 'Иероним', 'last': 'Стридонский'},
#  {'last': 'Аквитанского'},
#  {'first': 'Мартин', 'last': 'V'},
#  {'first': 'Флавий', 'last': 'Луций'},
#  {'first': 'Аврелий', 'last': 'Августин'},
#  {'first': 'Авит'},
#  {'first': 'Лукиан'},
#  {'first': 'Кафар', 'last': 'Гамалы'},
#  {'first': 'Анастасий', 'last': 'Библиотекарь'},
#  {'last': 'Аквитанский'},
#  {'last': 'Аквитанский'},
#  {'first': 'Поссидий'},
#  {'first': 'Марий', 'last': 'Меркатор'},
#  {'first': 'Иоанн', 'last': 'Кассиан'},
#  {'first': 'Иоанн', 'last': 'Кассиан'},
#  {'first': 'Пахомий', 'last': 'Великий'},
#  {'first': 'Вигилий'},
#  {'first': 'Фастидий'},
#  {'first': 'Целестин', 'last': 'I'},
#  {'first': 'Антонин', 'last': 'Гонорат'},
#  {'first': 'Викентий', 'last': 'Леринский'},
#  {'first': 'Евхерий', 'last': 'Лионский'},
#  {'first': 'Иларий', 'last': 'Арелатский'},
#  {'last': 'Аквитанский'},
#  {'first': 'Марцеллин', 'last': 'Комит'},
#  {'first': 'Петр', 'last': 'Хрисолог'},
#  {'first': 'Валериан'},
#  {'first': 'Сальвиан', 'last': 'Массилийский'},
#  {'first': 'Клавдиан', 'last': 'Мамерт'},
#  {'first': 'Патрик', 'last': 'Ирландский'},
#  {'first': 'Урбан'},
#  {'first': 'Евстафий'},
#  {'first': 'Василий', 'last': 'Кесарийский'},
#  {'first': 'Лев', 'last': 'I'},
#  {'first': 'Максим', 'last': 'Туринский'},
#  {'last': 'Луп'},
#  {'first': 'Виктор', 'last': 'Витенский'},
#  {'first': 'Сидоний', 'last': 'Аполлинарий'},
#  {'first': 'Цереалий', 'last': 'Касталланский'},
#  {'first': 'Евгений'},
#  {'first': 'Фауст'},
#  {'first': 'Феликс', 'last': 'III'},
#  {'first': 'Геннадий', 'last': 'Массилийский'},
#  {'first': 'Геласий', 'last': 'I'},
#  {'first': 'Авит', 'last': 'Вьеннский'},
#  {'first': 'Иоанн'},
#  {'first': 'Фаустин'},
#  {'first': 'Юлиан', 'last': 'Померий'},
#  {'first': 'Павлин', 'last': 'Ноланский'},
#  {'first': 'Клавдий', 'last': 'Марий'},
#  {'first': 'Павлин'},
#  {'last': 'Амоэн'},
#  {'first': 'Дрепаний', 'last': 'Флор'},
#  {'first': 'Симмах'},
#  {'first': 'Петр'},
#  {'first': 'Вигилий', 'last': 'Тапсский'},
#  {'first': 'Афанасий', 'last': 'Александрийский'},
#  {'first': 'Лев', 'last': 'I'},
#  {'first': 'Гельпидий', 'last': 'Рустик'},
#  {'first': 'Евгиппий'},
#  {'first': 'Эннодий'},
#  {'first': 'Иоанн', 'last': 'I'},
#  {'first': 'Эльпида'},
#  {'first': 'Феликс', 'last': 'IV'},
#  {'first': 'Бонифаций', 'last': 'II'},
#  {'last': 'Монтан'},
#  {'last': 'Руспийский'},
#  {'first': 'Иоанн', 'last': 'II'},
#  {'first': 'Агапит', 'last': 'I'},
#  {'first': 'Лаврентий'},
#  {'last': 'Новарский'},
#  {'first': 'Бенедикт', 'last': 'Нурсианский'},
#  {'first': 'Альберик'},
#  {'first': 'Дионисий', 'last': 'Малый'},
#  {'first': 'Ферранд', 'last': 'Фульгенций'},
#  {'last': 'Юст'},
#  {'first': 'Троян', 'last': 'Сентский'},
#  {'first': 'Понтиан', 'last': 'Африканец'},
#  {'first': 'Кесарий', 'last': 'Арелатский'},
#  {'last': 'Рустик'},
#  {'first': 'Лев'},
#  {'first': 'Юнилий'},
#  {'first': 'Маппин'},
#  {'first': 'Виктор'},
#  {'last': 'Трирский'},
#  {'first': 'Агнелл'},
#  {'first': 'Аврелиан', 'last': 'Арелатский'},
#  {'first': 'Примасий'},
#  {'first': 'Виктор', 'last': 'Туннунский'},
#  {'first': 'Вигилий'},
#  {'first': 'Юстиниан', 'last': 'I'},
#  {'first': 'Гильда', 'last': 'Премудрый'},
#  {'first': 'Пелагий', 'last': 'I'},
#  {'first': 'Кассиодор'},
#  {'first': 'Кассиодор'},
#  {'first': 'Григорий', 'last': 'Турский'},
#  {'first': 'Хильдеберт', 'last': 'I'},
#  {'first': 'Теодеберт', 'last': 'I'},
#  {'first': 'Теобальд'},
#  {'first': 'Хильдеберт', 'last': 'II'},
#  {'first': 'Сигеберт', 'last': 'III'},
#  {'first': 'Эрхамберт'},
#  {'first': 'Иоанн', 'last': 'III'},
#  {'first': 'Мартин', 'last': 'Бракарский'},
#  {'first': 'Герман'},
#  {'last': 'Фортунат'},
#  {'first': 'Радегунда'},
#  {'first': 'Бенедикт', 'last': 'I'},
#  {'first': 'Лициниан'},
#  {'first': 'Веран'},
#  {'first': 'Пелагий', 'last': 'II'},
#  {'first': 'Аунарий', 'last': 'Осерский'},
#  {'first': 'Лукулент'},
#  {'first': 'Иоанн', 'last': 'Арелатский'},
#  {'first': 'Иоанн', 'last': 'Бикларский'},
#  {'first': 'Леандр'},
#  {'first': 'Антоний'},
#  {'first': 'Флориан'},
#  {'first': 'Юстиниан', 'last': 'I'},
#  {'first': 'Теодорих', 'last': 'I'},
#  {'first': 'Хильдеберт', 'last': 'II'},
#  {'first': 'Дионисий', 'last': 'Малый'},
#  {'first': 'Урс'},
#  {'first': 'Герард', 'last': 'Воссио'},
#  {'first': 'Антоний', 'last': 'Дисципул'},
#  {'first': 'Леонтий'},
#  {'first': 'Анастасия'},
#  {'first': 'Иоанн', 'last': 'Дамаскин'},
#  {'first': 'Иаков', 'last': 'Биллион'},
#  {'first': 'Ефрем'},
#  {'first': 'Иаков', 'last': 'Диакон'},
#  {'first': 'Софроний', 'last': 'Иерусалимский'},
#  {'first': 'Павел', 'last': 'Диакон'},
#  {'first': 'Иоанн', 'last': 'Кассиан'},
#  {'first': 'Пелагия'},
#  {'last': 'Палладий'},
#  {'first': 'Гентиана', 'last': 'Гарвета'},
#  {'first': 'Иоанн'},
#  {'first': 'Гераклид', 'last': 'Александрийский'},
#  {'last': 'Палладий'},
#  {'first': 'Мартин', 'last': 'Бракарский'},
#  {'first': 'Геласий', 'last': 'I'},
#  {'first': 'Феодорит', 'last': 'Кирский'},
#  {'first': 'Гентиан', 'last': 'Гервет'},
#  {'first': 'Дамасий', 'last': 'I'},
#  {'first': 'Константин', 'last': 'I'},
#  {'first': 'Григорий', 'last': 'I'},
#  {'first': 'Иоанн', 'last': 'Диакон'},
#  {'first': 'Григорий', 'last': 'I'},
#  {'first': 'Григорий', 'last': 'I'},
#  {'first': 'Алульф'},
#  {'first': 'Евтропий'},
#  {'first': 'Тарра'},
#  {'first': 'Динам'},
#  {'first': 'Августин', 'last': 'Кентерберийский'},
#  {'first': 'Бонифаций', 'last': 'IV'},
#  {'first': 'Павел', 'last': 'Эмеритан'},
#  {'first': 'Тамай'},
#  {'first': 'Гундемар'},
#  {'first': 'Марк'},
#  {'first': 'Варнахарий'},
#  {'first': 'Альфан'},
#  {'first': 'Этельберт'},
#  {'last': 'Сисебут'},
#  {'first': 'Бертихрамн'},
#  {'first': 'Протандий'},
#  {'first': 'Бонифаций', 'last': 'V'},
#  {'first': 'Вер'},
#  {'first': 'Гонорий', 'last': 'I'},
#  {'first': 'Дагоберт', 'last': 'I'},
#  {'first': 'Аутберт'},
#  {'first': 'Иоанн', 'last': 'IV'},
#  {'first': 'Максим'},
#  {'first': 'Евтранд'},
#  {'first': 'Виктор'},
#  {'first': 'Браулио', 'last': 'Сарагосский'},
#  {'first': 'Тайо'},
#  {'first': 'Исидор', 'last': 'Севильский'},
#  {'first': 'Исидор', 'last': 'Севильским'},
#  {'first': 'Исидор'},
#  {'first': 'Теодор', 'last': 'I'},
#  {'first': 'Мавр'},
#  {'first': 'Мартин', 'last': 'I'},
#  {'first': 'Павел'},
#  {'first': 'Дезидерий'},
#  {'first': 'Донат'},
#  {'first': 'Ландерик'},
#  {'first': 'Сигеберт', 'last': 'III'},
#  {'last': 'Ливин'},
#  {'first': 'Евгений', 'last': 'III'},
#  {'first': 'Валерий'},
#  {'first': 'Валерий'},
#  {'first': 'Аннемунд'},
#  {'first': 'Элигий'},
#  {'first': 'Маркульф'},
#  {'first': 'Куммиан', 'last': 'Ирландец'},
#  {'first': 'Виталиан'},
#  {'first': 'Ион'},
#  {'last': 'Эльнонский'},
#  {'last': 'Фаро'},
#  {'first': 'Дон'},
#  {'first': 'Агафон'},
#  {'first': 'Дамиан'},
#  {'first': 'Аманд'},
#  {'first': 'Хильдерик', 'last': 'II'},
#  {'first': 'Дагоберт', 'last': 'II'},
#  {'first': 'Теодорих', 'last': 'III'},
#  {'last': 'Фортунат'},
#  {'first': 'Троклар'},
#  {'first': 'Адамнан'},
#  {'first': 'Адаман'},
#  {'first': 'Сергий', 'last': 'I'},
#  {'first': 'Иоанн', 'last': 'VI'},
#  {'first': 'Иоанн', 'last': 'VII'},
#  {'first': 'Альдхельм'},
#  {'first': 'Константин'},
#  {'first': 'Кеолфрид'},
#  {'first': 'Феликс'},
#  {'first': 'Бенедикт'},
#  {'first': 'Эгберт'},
#  {'first': 'Григорий', 'last': 'II'},
#  {'first': 'Григорий', 'last': 'III'},
#  {'first': 'Бонифаций'},
#  {'first': 'Захария'},
#  {'first': 'Стефан', 'last': 'II'},
#  {'last': 'Примин'},
#  {'first': 'Киприан'},
#  {'first': 'Хродеган'},
#  {'first': 'Павел', 'last': 'I'},
#  {'first': 'Стурмий'},
#  {'first': 'Фульды'},
#  {'first': 'Амвросий'},
#  {'first': 'Беневента'},
#  {'last': 'Беда'},
#  {'last': 'Беда'},
#  {'first': 'Павел', 'last': 'Диакон'},
#  {'first': 'Ландульф', 'last': 'Хитроумный'},
#  {'first': 'Ильдефонс', 'last': 'Толедский'},
#  {'first': 'Леодегарий'},
#  {'first': 'Лев', 'last': 'II'},
#  {'first': 'Бенедикт', 'last': 'II'},
#  {'first': 'Иоанн', 'last': 'V'},
#  {'first': 'Юлиан', 'last': 'Толедский'},
#  {'first': 'Лулл', 'last': 'Майнцский'},
#  {'first': 'Элипанд', 'last': 'Толедский'},
#  {'first': 'Феликс', 'last': 'Урхельский'},
#  {'first': 'Рахио'},
#  {'first': 'Ангильрамн', 'last': 'Мецский'},
#  {'first': 'Адриан', 'last': 'I'},
#  {'first': 'Петр'},
#  {'first': 'Катульф'},
#  {'last': 'Констант'},
#  {'first': 'Карл', 'last': 'Великий'},
#  {'first': 'Людовик', 'last': 'I'},
#  {'first': 'Бенедикт', 'last': 'Левит'},
#  {'first': 'Карл', 'last': 'Великий'},
#  {'first': 'Лев', 'last': 'III'},
#  {'first': 'Людовик', 'last': 'I'},
#  {'first': 'Генрих', 'last': 'I'},
#  {'first': 'Матильда', 'last': 'Тосканская'},
#  {'first': 'Рудольф', 'last': 'I'},
#  {'first': 'Адриан', 'last': 'I'},
#  {'first': 'Павлин', 'last': 'Аквилейский'},
#  {'last': 'Саксонский'},
#  {'first': 'Людгер', 'last': 'Мюнстерский'},
#  {'first': 'Фарнульф'},
#  {'first': 'Сен'},
#  {'first': 'Лейдрад'},
#  {'first': 'Амаларий', 'last': 'Фортунат'},
#  {'first': 'Теодор', 'last': 'Кентерберийский'},
#  {'first': 'Иоанн'},
#  {'first': 'Аскарий', 'last': 'Тусаредо'},
#  {'last': 'Смарагд'},
#  {'first': 'Людовик', 'last': 'I'},
#  {'first': 'Магн'},
#  {'first': 'Лев', 'last': 'III'},
#  {'last': 'Кура'},
#  {'first': 'Седулий', 'last': 'Скот'},
#  {'first': 'Антоний'},
#  {'first': 'Исайи'},
#  {'first': 'Серапион'},
#  {'first': 'Макарий'},
#  {'first': 'Руфина'},
#  {'first': 'Гримлаик'},
#  {'first': 'Афанасий', 'last': 'Александрийского'},
#  {'first': 'Вигилий'},
#  {'first': 'Бенедикт', 'last': 'Анианский'},
#  {'first': 'Агобард', 'last': 'Лионский'},
#  {'first': 'Григорий', 'last': 'IV'},
#  {'first': 'Эйнхард'},
#  {'first': 'Клавдий', 'last': 'Туринский'},
#  {'first': 'Людовик', 'last': 'I'},
#  {'first': 'Теодульф', 'last': 'Орлеанский'},
#  {'first': 'Эйгиль', 'last': 'Фульдский'},
#  {'first': 'Адальхард'},
#  {'last': 'Корвейский'},
#  {'first': 'Эрмольд', 'last': 'Нигелл'},
#  {'first': 'Евгений', 'last': 'II'},
#  {'first': 'Халитгарий'},
#  {'first': 'Фредегиз'},
#  {'first': 'Иеремия'},
#  {'first': 'Ансегис'},
#  {'first': 'Фонтенелля'},
#  {'first': 'Хильдерик'},
#  {'last': 'Кассинский'},
#  {'first': 'Алдрик'},
#  {'first': 'Амаларий', 'last': 'Мецский'},
#  {'last': 'Фульдский'},
#  {'first': 'Ион', 'last': 'Орлеанский'},
#  {'first': 'Хильдемар'},
#  {'last': 'Ламберт'},
#  {'first': 'Теган'},
#  {'last': 'Трирский'},
#  {'first': 'Агнелл', 'last': 'Равеннский'},
#  {'first': 'Григорий', 'last': 'IV'},
#  {'first': 'Фротарий'},
#  {'first': 'Ильдефонс'},
#  {'first': 'Иосиф'},
#  {'first': 'Сергий', 'last': 'II'},
#  {'first': 'Фрекульф'},
#  {'first': 'Сен'},
#  {'first': 'Христиане', 'last': 'Друтмар'},
#  {'first': 'Аврелиан', 'last': 'Рекомский'},
#  {'first': 'Мавр', 'last': 'Рабан'},
#  {'first': 'Мавр', 'last': 'Рабан'},
#  {'first': 'Валафрид', 'last': 'Страбон'},
#  {'first': 'Аудрад'},
#  {'last': 'Сансский'},
#  {'first': 'Алдрик'},
#  {'first': 'Ангел'},
#  {'first': 'Лев', 'last': 'IV'},
#  {'first': 'Бенедикт', 'last': 'III'},
#  {'first': 'Евлогий', 'last': 'Толедский'},
#  {'first': 'Сен', 'last': 'Аймоний'},
#  {'first': 'Эрманрик'},
#  {'first': 'Эрхамберт'},
#  {'first': 'Нитхард'},
#  {'first': 'Амуло'},
#  {'first': 'Хаймон', 'last': 'Хальберштадтский'},
#  {'first': 'Хаймон', 'last': 'Хальберштадтский'},
#  {'first': 'Хаймон', 'last': 'Хальберштадтский'},
#  {'first': 'Ансгар'},
#  {'first': 'Григорий', 'last': 'IV'},
#  {'first': 'Флор', 'last': 'Лионский'},
#  {'last': 'Серват'},
#  {'first': 'Родульф'},
#  {'last': 'Суассонский'},
#  {'first': 'Николай', 'last': 'I'},
#  {'first': 'Радберт', 'last': 'Пасхазий'},
#  {'first': 'Ратрамн', 'last': 'Корбийский'},
#  {'last': 'Готшальк'},
#  {'first': 'Гюнтар', 'last': 'Кельнский'},
#  {'last': 'Шалонский'},
#  {'first': 'Альваро', 'last': 'Кордовский'},
#  {'first': 'Леовигильд', 'last': 'Кордовский'},
#  {'first': 'Киприан', 'last': 'Кордовский'},
#  {'first': 'Бернард'},
#  {'first': 'Вандальберт', 'last': 'Прюмский'},
#  {'last': 'Эней'},
#  {'first': 'Герард'},
#  {'last': 'Турский'},
#  {'first': 'Исо', 'last': 'Санкт'},
#  {'first': 'Гримальд'},
#  {'first': 'Милон'},
#  {'first': 'Аманда'},
#  {'first': 'Вулфад'},
#  {'first': 'Иоанн', 'last': 'Скот'},
#  {'first': 'Адриан', 'last': 'II'},
#  {'first': 'Адон', 'last': 'Вьеннский'},
#  {'first': 'Узуард'},
#  {'first': 'Сен'},
#  {'first': 'Карл', 'last': 'II'},
#  {'first': 'Адревальд'},
#  {'first': 'Флери'},
#  {'first': 'Лан'},
#  {'first': 'Исаак'},
#  {'first': 'Хейрик', 'last': 'Осерский'},
#  {'first': 'Иоанн', 'last': 'VIII'},
#  {'first': 'Марин', 'last': 'I'},
#  {'first': 'Адриан', 'last': 'III'},
#  {'first': 'Бертарий'},
#  {'first': 'Хармот'},
#  {'first': 'Римберт'},
#  {'first': 'Сен', 'last': 'Аймоний'},
#  {'last': 'Галленский'},
#  {'first': 'Анастасий', 'last': 'Библиотекарь'},
#  {'first': 'Франциск', 'last': 'Бланхин'},
#  {'first': 'Григорий'},
#  {'first': 'Анастасий', 'last': 'Библиотекарь'},
#  {'first': 'Анастасий', 'last': 'Библиотекарь'},
#  {'first': 'Эрхемберт'},
#  {'first': 'Ангильберт'},
#  {'last': 'Корвейский'},
#  {'first': 'Стефан', 'last': 'V'},
#  {'first': 'Стефан', 'last': 'VI'},
#  {'first': 'Роман'},
#  {'first': 'Вольфхард'},
#  {'last': 'Хасенриетанский'},
#  {'first': 'Евтропий', 'last': 'Лангобард'},
#  {'first': 'Лев', 'last': 'III'},
#  {'first': 'Стефан', 'last': 'IV'},
#  {'first': 'Евгений', 'last': 'II'},
#  {'first': 'Григорий', 'last': 'IV'},
#  {'first': 'Сергий', 'last': 'II'},
#  {'first': 'Лев', 'last': 'IV'},
#  {'first': 'Бенедикт', 'last': 'III'},
#  {'first': 'Николай', 'last': 'I'},
#  {'first': 'Адриан', 'last': 'II'},
#  {'first': 'Стефан', 'last': 'V'},
#  {'first': 'Псевдо'},
#  {'first': 'Исидор', 'last': 'Меркатор'},
#  {'first': 'Рикульф'},
#  {'first': 'Манцио'},
#  {'first': 'Иоанн', 'last': 'IX'},
#  {'first': 'Бенедикт', 'last': 'IV'},
#  {'first': 'Христофор'},
#  {'last': 'Осерский'},
#  {'first': 'Сергий', 'last': 'III'},
#  {'last': 'Галленский'},
#  {'first': 'Анастасий', 'last': 'III'},
#  {'last': 'Прюмский'},
#  {'first': 'Бертарий', 'last': 'Верденский'},
#  {'first': 'Роберт', 'last': 'I'},
#  {'last': 'Меца'},
#  {'last': 'Саломон'},
#  {'first': 'Одилон'},
#  {'first': 'Стефан'},
#  {'last': 'Дольский'},
#  {'first': 'Сен', 'last': 'Аббон'},
#  {'first': 'Дадон'},
#  {'first': 'Агий'},
#  {'first': 'Иоанн', 'last': 'X'},
#  {'first': 'Лев', 'last': 'VI'},
#  {'first': 'Хукбальд', 'last': 'Сен'},
#  {'first': 'Стефан', 'last': 'VII'},
#  {'first': 'Иоанн', 'last': 'XI'},
#  {'first': 'Сеульф'},
#  {'first': 'Лев', 'last': 'VII'},
#  {'first': 'Стефан', 'last': 'VIII'},
#  {'first': 'Одон', 'last': 'Клюнийский'},
#  {'first': 'Людовик', 'last': 'III'},
#  {'first': 'Леотальд', 'last': 'Маконский'},
#  {'first': 'Клермон', 'last': 'Гийом'},
#  {'last': 'Ставоренский'},
#  {'first': 'Марин', 'last': 'II'},
#  {'first': 'Козьма', 'last': 'Япиг'},
#  {'first': 'Иоанн'},
#  {'first': 'Лаврентий', 'last': 'Кассинский'},
#  {'first': 'Агапит', 'last': 'II'},
#  {'first': 'Одон'},
#  {'first': 'Артольд'},
#  {'first': 'Одальрик'},
#  {'first': 'Сигехард', 'last': 'Трирский'},
#  {'first': 'Иоанн', 'last': 'XII'},
#  {'last': 'Верчелльский'},
#  {'first': 'Адальгер'},
#  {'first': 'Бруно'},
#  {'first': 'Лев', 'last': 'VIII'},
#  {'first': 'Вибольд'},
#  {'last': 'Шалонский'},
#  {'first': 'Флодоард'},
#  {'first': 'Гумпольд'},
#  {'first': 'Эралий'},
#  {'first': 'Иоанн', 'last': 'XIII'},
#  {'first': 'Ульрих'},
#  {'first': 'Бенедикт', 'last': 'VI'},
#  {'first': 'Сен', 'last': 'Фольквин'},
#  {'last': 'Новарский'},
#  {'first': 'Рихард'},
#  {'first': 'Флери'},
#  {'first': 'Адальберт', 'last': 'Мецский'},
#  {'first': 'Хельперик'},
#  {'last': 'Галленский'},
#  {'last': 'Бернер'},
#  {'last': 'Гумоларский'},
#  {'first': 'Этельвольд', 'last': 'Уинчестерский'},
#  {'first': 'Видукинд', 'last': 'Корвейский'},
#  {'first': 'Иоанн'},
#  {'last': 'Ошский'},
#  {'first': 'Бенедикт', 'last': 'VII'},
#  {'first': 'Иоанн', 'last': 'XIV'},
#  {'first': 'Теодерик'},
#  {'last': 'Дертонский'},
#  {'first': 'Лоббе'},
#  {'first': 'Эркембальд'},
#  {'last': 'Адсон'},
#  {'last': 'Клюнийский'},
#  {'last': 'Клюнийский'},
#  {'first': 'Летальд'},
#  {'first': 'Иоанн', 'last': 'XV'},
#  {'first': 'Гвидо', 'last': 'II'},
#  {'last': 'Ле'},
#  {'first': 'Адальберт'},
#  {'first': 'Григорий', 'last': 'V'},
#  {'first': 'Конрад', 'last': 'Кельт'},
#  {'first': 'Хросвита', 'last': 'Гандерсгеймская'},
#  {'first': 'Герард', 'last': 'Суассонский'},
#  {'first': 'Теральд'},
#  {'first': 'Амблалард'},
#  {'last': 'Солиньякский'},
#  {'first': 'Альфред', 'last': 'Великий'},
#  {'first': 'Эдуард', 'last': 'I'},
#  {'first': 'Эдмунд'},
#  {'first': 'Эдгар'},
#  {'last': 'Оттона'},
#  {'last': 'Оттона'},
#  {'first': 'Бенедикт'},
#  {'first': 'Сильвестр', 'last': 'II'},
#  {'first': 'Пурхард'},
#  {'first': 'Тиепальд'},
#  {'first': 'Альберт'},
#  {'first': 'Рорико', 'last': 'Муассакский'},
#  {'last': 'Эмуэн'},
#  {'first': 'Иоанн', 'last': 'Диакон'},
#  {'first': 'Херигер', 'last': 'Лоббский'},
#  {'first': 'Титмар'},
#  {'first': 'Генрих', 'last': 'Император'},
#  {'first': 'Тангмар', 'last': 'Хильдесхаймский'},
#  {'last': 'Альперт'},
#  {'first': 'Бурхард'},
#  {'first': 'Адельбольд'},
#  {'first': 'Ромуальд'},
#  {'last': 'Камальдуленский'},
#  {'first': 'Адемар', 'last': 'Ангулемский'},
#  {'first': 'Бернард', 'last': 'Анжерский'},
#  {'first': 'Фульберт'},
#  {'first': 'Гвидон', 'last': 'Аретинский'},
#  {'last': 'Хильдесхаймские'},
#  {'last': 'Ламберт'},
#  {'first': 'Дудон', 'last': 'Сен'},
#  {'first': 'Гослен'},
#  {'first': 'Лан'},
#  {'first': 'Сен'},
#  {'first': 'Роберт', 'last': 'II'},
#  {'first': 'Мегинфрид', 'last': 'Магдебургский'},
#  {'first': 'Арнольд', 'last': 'Эммерамский'},
#  {'first': 'Эбал'},
#  {'first': 'Иоанн', 'last': 'XIX'},
#  {'first': 'Годехард'},
#  {'last': 'Ротский'},
#  {'first': 'Фроумунд'},
#  {'first': 'Эберхард'},
#  {'first': 'Перингер'},
#  {'first': 'Эллингер'},
#  {'first': 'Удальрик'},
#  {'last': 'Годескальк'},
#  {'first': 'Отельбольд'},
#  {'first': 'Бенедикт', 'last': 'IX'},
#  {'first': 'Хериберт'},
#  {'first': 'Ангельранн'},
#  {'first': 'Сен'},
#  {'first': 'Роберт'},
#  {'first': 'Гарсия'},
#  {'first': 'Доминик'},
#  {'first': 'Бруно'},
#  {'last': 'Вюрцбургский'},
#  {'first': 'Григорий', 'last': 'VI'},
#  {'first': 'Климент', 'last': 'II'},
#  {'last': 'Олива'},
#  {'last': 'Осонский'},
#  {'first': 'Рауль', 'last': 'Глабер'},
#  {'first': 'Сифрид'},
#  {'first': 'Одоранн', 'last': 'Сансский'},
#  {'first': 'Одилон', 'last': 'Клюнийский'},
#  {'first': 'Герард'},
#  {'first': 'Гуго'},
#  {'first': 'Халинард'},
#  {'first': 'Гвидо'},
#  {'first': 'Ансельм', 'last': 'Реймсский'},
#  {'first': 'Герман'},
#  {'first': 'Лев', 'last': 'IX'},
#  {'first': 'Михаил', 'last': 'Керуларий'},
#  {'first': 'Иоанн', 'last': 'I'},
#  {'last': 'Фекамский'},
#  {'first': 'Виктор', 'last': 'II'},
#  {'first': 'Беренгарий', 'last': 'Нарбоннский'},
#  {'first': 'Бовэ'},
#  {'first': 'Стефан', 'last': 'X'},
#  {'first': 'Иоанн'},
#  {'last': 'Сабинский'},
#  {'first': 'Гумберт'},
#  {'first': 'Николай', 'last': 'II'},
#  {'first': 'Фролланд'},
#  {'first': 'Видрик'},
#  {'last': 'Льежский'},
#  {'first': 'Маврилий'},
#  {'first': 'Раймбальд'},
#  {'first': 'Гервасий'},
#  {'first': 'Леодегарий'},
#  {'last': 'Вьеннский'},
#  {'first': 'Стефан'},
#  {'first': 'Лев'},
#  {'first': 'Анно'},
#  {'first': 'Петр', 'last': 'Дамиани'},
#  {'first': 'Александр', 'last': 'II'},
#  {'first': 'Павел', 'last': 'V'},
#  {'first': 'Отлон', 'last': 'Санкт'},
#  {'first': 'Адам', 'last': 'Бременский'},
#  {'first': 'Гвальберт', 'last': 'Валлумброзан'},
#  {'first': 'Гундехар'},
#  {'last': 'Ламберт'},
#  {'first': 'Петр'},
#  {'first': 'Александр', 'last': 'II'},
#  {'first': 'Гуго'},
#  {'first': 'Лиетберт'},
#  {'first': 'Рогерий'},
#  {'first': 'Гвидон'},
#  {'first': 'Иоанн', 'last': 'Авраншский'},
#  {'first': 'Арнульф', 'last': 'Миланский'},
#  {'first': 'Теодорик', 'last': 'Падерборнский'},
#  {'first': 'Бертольд', 'last': 'Констанцский'},
#  {'first': 'Иоанн'},
#  {'last': 'Фекамский'},
#  {'first': 'Бруно', 'last': 'Кверфуртский'},
#  {'last': 'Хаснонский'},
#  {'first': 'Реналл', 'last': 'Барселонский'},
#  {'first': 'Мариан', 'last': 'Скот'},
#  {'first': 'Ландульф', 'last': 'Миланский'},
#  {'first': 'Геральд'},
#  {'first': 'Фолькард', 'last': 'Сен'},
#  {'first': 'Евсевий'},
#  {'first': 'Альфан', 'last': 'I'},
#  {'last': 'Кассинский'},
#  {'first': 'Григорий', 'last': 'VII'},
#  {'first': 'Климент', 'last': 'III'},
#  {'first': 'Гебхард'},
#  {'first': 'Матильда'},
#  {'first': 'Бернальд', 'last': 'Констанцский'},
#  {'first': 'Стефан'},
#  {'first': 'Самуэль', 'last': 'Морохиниан'},
#  {'last': 'Осберн'},
#  {'first': 'Бартоломей'},
#  {'first': 'Бернард'},
#  {'first': 'Анастасий', 'last': 'Клюнийский'},
#  {'last': 'ди'},
#  {'first': 'Удальрик'},
#  {'first': 'Клюни'},
#  {'last': 'Жюмьежский'},
#  {'first': 'Виктор', 'last': 'III'},
#  {'first': 'Гауфрид', 'last': 'Малатерра'},
#  {'first': 'Сурита', 'last': 'Иероним'},
#  {'first': 'Вильгельм', 'last': 'I'},
#  {'last': 'Троарский'},
#  {'first': 'Эбрард', 'last': 'Ваттенский'},
#  {'last': 'Бекский'},
#  {'last': 'Бекский'},
#  {'last': 'Бозо'},
#  {'last': 'Бекский'},
#  {'first': 'Теобальд'},
#  {'first': 'Летард'},
#  {'last': 'Бекский'},
#  {'first': 'Августин', 'last': 'Кентерберийский'},
#  {'first': 'Вильгельм'},
#  {'first': 'Вильгельм'},
#  {'first': 'Хериманн'},
#  {'first': 'Теодорик'},
#  {'first': 'Гвидо'},
#  {'last': 'Фарфенский'},
#  {'first': 'Генрих', 'last': 'Помпозиан'},
#  {'first': 'Роберт'},
#  {'first': 'Тумбалены'},
#  {'first': 'Герард', 'last': 'II'},
#  {'first': 'Рейнальд', 'last': 'I'},
#  {'first': 'Иоанн', 'last': 'Коттон'},
#  {'last': 'Корвейский'},
#  {'first': 'Гиллеберт'},
#  {'last': 'Элнонский'},
#  {'first': 'Клюзи'},
#  {'first': 'Хемминг', 'last': 'Вустерский'},
#  {'first': 'Агано'},
#  {'first': 'Ольдарик'},
#  {'first': 'Бернард'},
#  {'last': 'Мо'},
#  {'first': 'Константин', 'last': 'Африканец'},
#  {'first': 'Иоанн', 'last': 'Гарландский'},
#  {'first': 'Руфин'},
#  {'first': 'Урбан', 'last': 'II'},
#  {'first': 'Медиани'},
#  {'last': 'Гудин'},
#  {'first': 'Видо'},
#  {'first': 'Раймунд', 'last': 'Арналли'},
#  {'first': 'Альвало'},
#  {'first': 'Анселл'},
#  {'first': 'Бернелин'},
#  {'last': 'Регенсбургский'},
#  {'first': 'Радульф', 'last': 'Бургундского'},
#  {'first': 'Генрих', 'last': 'I'},
#  {'first': 'Конрад', 'last': 'II'},
#  {'first': 'Генрих', 'last': 'III'},
#  {'first': 'Генрих', 'last': 'IV'},
#  {'last': 'Английский'},
#  {'first': 'Макбет', 'last': 'Шотландский'},
#  {'first': 'Эдуард', 'last': 'III'},
#  {'first': 'Стефан', 'last': 'I'},
#  {'first': 'Бржетислав', 'last': 'Богемского'},
#  {'first': 'Ангильберт'},
#  {'first': 'Андрей', 'last': 'Бергамский'},
#  {'first': 'Петр', 'last': 'Библиотекарь'},
#  {'first': 'Матильда'},
#  {'first': 'Иоанн', 'last': 'Смера'},
#  {'first': 'Бруно', 'last': 'Кельнский'},
#  {'first': 'Бруно', 'last': 'Кельнский'},
#  {'first': 'Бернард'},
#  {'first': 'Иоанн', 'last': 'Картезианец'},
#  {'first': 'Гуго'},
#  {'last': 'Ламберт'},
#  {'first': 'Гуго'},
#  {'first': 'Вольфельм'},
#  {'first': 'Эккехард'},
#  {'first': 'Теодерик', 'last': 'Трирский'},
#  {'first': 'Эбервин', 'last': 'Трирский'},
#  {'first': 'Стефан', 'last': 'Льежский'},
#  {'first': 'Госцелин', 'last': 'Кентерберийский'},
#  {'last': 'Луп'},
#  {'first': 'Манхи', 'last': 'Турский'},
#  {'first': 'Манегальд'},
#  {'first': 'Павел', 'last': 'Шартрский'},
#  {'first': 'Готфрид', 'last': 'Бульонский'},
#  {'first': 'Ида'},
#  {'last': 'Болонская'},
#  {'first': 'Ансельм'},
#  {'first': 'Гуго'},
#  {'first': 'Раймунд'},
#  {'last': 'Ирландский'},
#  {'first': 'Раймунд', 'last': 'Ажильский'},
#  {'first': 'Роберт'},
#  {'first': 'Петр', 'last': 'Тудебод'},
#  {'first': 'Фульхерий', 'last': 'Шартрский'},
#  {'first': 'Фретелл'},
#  {'first': 'Иоанн'},
#  {'last': 'Вюрцбургский'},
#  {'last': 'Иерусалимский'},
#  {'first': 'Людовик', 'last': 'VII'},
#  {'first': 'Людовик', 'last': 'IX'},
#  {'first': 'Радульф', 'last': 'Арденс'},
#  {'first': 'Томас'},
#  {'first': 'Рихард'},
#  {'last': 'Думелльский'},
#  {'first': 'Альберик'},
#  {'first': 'Сулькард'},
#  {'first': 'Амат'},
#  {'first': 'Жироне'},
#  {'first': 'Поппо'},
#  {'first': 'Ансельм', 'last': 'IV'},
#  {'first': 'Гвиберт', 'last': 'Ножанский'},
#  {'first': 'Герман'},
#  {'last': 'Жоффруа'},
#  {'first': 'Теодерик'},
#  {'first': 'Тиофрид'},
#  {'first': 'Суавий'},
#  {'first': 'Фолькард'},
#  {'first': 'Лоббе'},
#  {'first': 'Адельгорий'},
#  {'first': 'Гуго'},
#  {'first': 'Петр', 'last': 'Альфонси'},
#  {'first': 'Гальтер'},
#  {'first': 'Литберт'},
#  {'first': 'Вернер'},
#  {'first': 'Роберт'},
#  {'first': 'Ансельм', 'last': 'Кентерберийский'},
#  {'first': 'Ансельм', 'last': 'Кентерберийский'},
#  {'first': 'Филипп', 'last': 'I'},
#  {'first': 'Гуго'},
#  {'first': 'Клюня'},
#  {'last': 'Гильберт'},
#  {'first': 'Гислеберт', 'last': 'Криспин'},
#  {'first': 'Сигеберт'},
#  {'last': 'Галл'},
#  {'first': 'Беренгоз'},
#  {'last': 'Трирский'},
#  {'first': 'Иоанн', 'last': 'Марсикан'},
#  {'first': 'Родульф', 'last': 'Тортарий'},
#  {'last': 'Шартрский'},
#  {'last': 'Шартрский'},
#  {'last': 'Ламберт'},
#  {'last': 'Аррасский'},
#  {'first': 'Франциск', 'last': 'Камен'},
#  {'first': 'Анселл'},
#  {'first': 'Реймбальд'},
#  {'last': 'Льежский'},
#  {'first': 'Иоанн'},
#  {'first': 'Петр', 'last': 'Хрисолан'},
#  {'first': 'Роберт'},
#  {'first': 'Петр'},
#  {'first': 'Гоффрид'},
#  {'last': 'Вандомский'},
#  {'first': 'Иоанн', 'last': 'Диакон'},
#  {'first': 'Ансельм', 'last': 'Лаонский'},
#  {'first': 'Рихард'},
#  {'first': 'Геласий', 'last': 'II'},
#  {'first': 'Лаврентий', 'last': 'Веронский'},
#  {'first': 'Петр'},
#  {'first': 'Григорий'},
#  {'first': 'Теобальд', 'last': 'Эстампский'},
#  {'first': 'Тегер'},
#  {'first': 'Гуго'},
#  {'first': 'Гуго', 'last': 'Анжерский'},
#  {'first': 'Радульф'},
#  {'first': 'Конон'},
#  {'first': 'Эрнульф'},
#  {'first': 'Арнальд'},
#  {'last': 'Сансский'},
#  {'first': 'Понтий'},
#  {'first': 'Иоанн', 'last': 'Констанцский'},
#  {'first': 'Бруно', 'last': 'Астийский'},
#  {'last': 'Монте'},
#  {'first': 'Бруно', 'last': 'Астийский'},
#  {'last': 'Монте'},
#  {'first': 'Козьма', 'last': 'Пражский'},
#  {'last': 'Сазавский'},
#  {'first': 'Альберик', 'last': 'Аахенский'},
#  {'last': 'Франко'},
#  {'first': 'Аффлигия'},
#  {'first': 'Гуго'},
#  {'first': 'Понтий'},
#  {'first': 'Клюня'},
#  {'first': 'Петр', 'last': 'Леонский'},
#  {'first': 'Григорий'},
#  {'first': 'Иоанн', 'last': 'Михиэльский'},
#  {'last': 'Теруанский'},
#  {'first': 'Гальберт'},
#  {'first': 'Бальдерик', 'last': 'Дольский'},
#  {'first': 'Гонорий', 'last': 'II'},
#  {'first': 'Вивиан'},
#  {'first': 'Гауссельм'},
#  {'first': 'Аббауд'},
#  {'first': 'Бруно'},
#  {'first': 'Фридерик'},
#  {'first': 'Рихард'},
#  {'last': 'Фрателльский'},
#  {'first': 'Стефан'},
#  {'first': 'Иоанн'},
#  {'first': 'Гуго'},
#  {'first': 'Руперт'},
#  {'first': 'Руперт'},
#  {'first': 'Роберт'},
#  {'first': 'Германн'},
#  {'last': 'Удаскальк'},
#  {'first': 'Мунио'},
#  {'first': 'Норберт'},
#  {'first': 'Хильдеберт'},
#  {'first': 'Гонорий', 'last': 'Отенский'},
#  {'first': 'Стефан'},
#  {'last': 'Отенский'},
#  {'first': 'Герард'},
#  {'first': 'Оддо', 'last': 'Реймсский'},
#  {'first': 'Адальберт'},
#  {'first': 'Райнальд', 'last': 'II'},
#  {'first': 'Ольдегарий'},
#  {'first': 'Гауффрид'},
#  {'first': 'Родульф'},
#  {'first': 'Сен'},
#  {'first': 'Лев', 'last': 'Остийский'},
#  {'first': 'Петр', 'last': 'Диакон'},
#  {'last': 'Фалько'},
#  {'first': 'Матфей'},
#  {'last': 'Гвалтер'},
#  {'first': 'Гауфрид'},
#  {'last': 'Шалонский'},
#  {'first': 'Стефан'},
#  {'first': 'Гуго'},
#  {'first': 'Ландульф', 'last': 'Младший'},
#  {'first': 'Харнульф'},
#  {'last': 'Уденбургский'},
#  {'first': 'Годефрид'},
#  {'first': 'Лизиард'},
#  {'first': 'Гуго', 'last': 'Сен'},
#  {'first': 'Гуго', 'last': 'Сен'},
#  {'first': 'Иоанн', 'last': 'Корнуолльский'},
#  {'first': 'Роберт', 'last': 'Павлул'},
#  {'first': 'Абеляр'},
#  {'first': 'Пьер'},
#  {'first': 'Иларий'},
#  {'first': 'Абеляр'},
#  {'first': 'Петр', 'last': 'Беренгарий'},
#  {'first': 'Абеляр'},
#  {'first': 'Иннокентий', 'last': 'III'},
#  {'first': 'Вулгрин'},
#  {'first': 'Бенедикт'},
#  {'first': 'Иоанн', 'last': 'XIX'},
#  {'first': 'Целестин', 'last': 'II'},
#  {'first': 'Луций', 'last': 'II'},
#  {'first': 'Вильям', 'last': 'Мальмсберийский'},
#  {'first': 'Гуго', 'last': 'Фарсит'},
#  {'first': 'Монтис'},
#  {'first': 'Герман'},
#  {'first': 'Теульф'},
#  {'first': 'Иоанн'},
#  {'first': 'Альгер', 'last': 'Льежский'},
#  {'first': 'Генрих'},
#  {'first': 'Евгений', 'last': 'III'},
#  {'first': 'Ульгерий'},
#  {'last': 'Гильдебранд'},
#  {'last': 'Дижонский'},
#  {'first': 'Петр', 'last': 'Дижонский'},
#  {'first': 'Хериберт'},
#  {'first': 'Райнард'},
#  {'last': 'Кистекский'},
#  {'first': 'Гуго'},
#  {'last': 'Макон'},
#  {'first': 'Понтиньи'},
#  {'first': 'Бернард', 'last': 'Клервоский'},
#  {'first': 'Бернард', 'last': 'Клервоский'},
#  {'first': 'Гиллеберт'},
#  {'first': 'Гауффрид'},
#  {'first': 'Николай', 'last': 'Клервоский'},
#  {'first': 'Огерий'},
#  {'first': 'Гверрик'},
#  {'first': 'Иньи'},
#  {'first': 'Арнульф'},
#  {'first': 'Гверрик'},
#  {'first': 'Иньи'},
#  {'first': 'Бернар', 'last': 'Клервоский'},
#  {'first': 'Филофей'},
#  {'first': 'Николай', 'last': 'Хоквилль'},
#  {'last': 'Батист'},
#  {'first': 'Гоффрид'},
#  {'first': 'Захария', 'last': 'Хризополитан'},
#  {'first': 'Захария'},
#  {'first': 'Роберт', 'last': 'Пулл'},
#  {'first': 'Сугерий'},
#  {'first': 'Людовик', 'last': 'VII'},
#  {'last': 'Жослен'},
#  {'first': 'Ордерик', 'last': 'Виталий'},
#  {'first': 'Гверрик'},
#  {'first': 'Иньи'},
#  {'first': 'Анастасий', 'last': 'IV'},
#  {'first': 'Ансельм'},
#  {'last': 'Хафельбергский'},
#  {'first': 'Жильбер', 'last': 'Порретанский'},
#  {'first': 'Гуго', 'last': 'Метелл'},
#  {'first': 'Амедей'},
#  {'first': 'Николай', 'last': 'Клюнийский'},
#  ...]

# %%
# Dates
dates
# Out:
# [Date(
#      year=1855,
#      month=None,
#      day=None
#  ),
#  None]

# %%
# Organisations
organisations
# Out:
# ['Patrologia Latina (Латинская патрология',
#  'Карфагенский собор',
#  'Халкидонский собор',
#  'Парадиз',
#  'Хроника',
#  'Безансона',
#  'Франкфуртский синод',
#  'Генеалогия Карл Великий',
#  'Лондонский собор',
#  'Кведлинбургские анналы',
#  'Chronicon Petrishuensis',
#  'Деяния святых мучеников Арнальда и Герлембальда',
#  'Майнцский собор',
#  'Панегирик император Беренгарию',
#  'Деяния епископов Меца',
#  'Анналы св. Витона Верденского',
#  'Одо',
#  'Во-де-Серне']

# %%
person_fact = fact(
    'Person',
    ['name', 'position']
)

position_fact = fact(
    'Position',
    ['position']
)

name_fact = fact(
    'Name',
    ['first', 'last', 'number', 'nickname']
)

post_rule = rule(
    '(', 
    gram('NOUN').repeatable().interpretation(position_fact.position), 
    ')'
).interpretation(position_fact)

name_rule = rule(
    and_(gram('Name'), is_capitalized()).interpretation(name_fact.first),
    and_(gram('NOUN'), is_capitalized()).repeatable().optional().interpretation(name_fact.last),
    type('LATIN').optional().interpretation(name_fact.number),
    gram('ADJF').optional().interpretation(name_fact.nickname),
).interpretation(name_fact)

person_rule = rule(
    name_rule.interpretation(person_fact.name), 
    post_rule.optional().interpretation(person_fact.position),
).interpretation(person_fact)

person_parser = Parser(person_rule)

# %%
# Better persons
for sent in doc.sents:
    parsed = person_parser.find(sent.text)
    if parsed:
        print(parsed.fact)
# Out:
# Person(name=Name(first='Минем', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Минь', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='В', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Тертуллиан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Феликс', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адама', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Корнелий', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Луций', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Стефан', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Морцелл', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дионисий', last=None, number=None, nickname='Александрийский'), position=None)
# Person(name=Name(first='Феликс', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Евтихиан', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Гай', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Коммодиан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Викторин', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Магнет', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Марцеллин', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Евсевий', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Мильтиад', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Константин', last=None, number='I', nickname='Великий'), position=None)
# Person(name=Name(first='Назарий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бурдигалы', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Сильвестр', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Марк', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Юлий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Викторин', last='Африканец', number=None, nickname=None), position=None)
# Person(name=Name(first='Осий', last=None, number=None, nickname='Кордовский'), position=None)
# Person(name=Name(first='Либерий', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Потамий', last=None, number=None, nickname=None), position=Position(position='епископ'))
# Person(name=Name(first='Евсевий', last=None, number=None, nickname='Верчелльский'), position=None)
# Person(name=Name(first='Фирмик', last='Матерн', number=None, nickname=None), position=None)
# Person(name=Name(first='Фаустин', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дамасий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Викторий', last=None, number=None, nickname='Аквитанский'), position=None)
# Person(name=Name(first='Феодосий', last=None, number='I', nickname='Великий'), position=None)
# Person(name=Name(first='Вигилий', last=None, number=None, nickname=None), position=Position(position='епископ'))
# Person(name=Name(first='Дионисий', last='Филокал', number=None, nickname=None), position=None)
# Person(name=Name(first='Полемей', last='Сильвий', number=None, nickname=None), position=None)
# Person(name=Name(first='Люцифер', last=None, number=None, nickname='Калаританский'), position=None)
# Person(name=Name(first='Юлий', last='Гилариан', number=None, nickname=None), position=None)
# Person(name=Name(first='Аврелий', last='Симмах', number=None, nickname=None), position=None)
# Person(name=Name(first='Максим', last='Грамматик', number=None, nickname=None), position=None)
# Person(name=Name(first='Клавдий', last='Мамертин', number=None, nickname=None), position=Position(position='панегирист'))
# Person(name=Name(first='Публий', last='Виктор', number=None, nickname=None), position=None)
# Person(name=Name(first='Ульфила', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Целий', last=None, number=None, nickname='Седулий'), position=None)
# Person(name=Name(first='Фебадий', last=None, number=None, nickname=None), position=Position(position='епископ Аженский'))
# Person(name=Name(first='Павлин', last=None, number=None, nickname='Медиоланский'), position=None)
# Person(name=Name(first='Анастасий', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иннокентий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Зосима', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бонифаций', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Аврелий', last=None, number=None, nickname='Карфагенский'), position=None)
# Person(name=Name(first='Бахиарий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Закхей', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Евагрий', last=None, number=None, nickname='Понтийский'), position=Position(position='перевод'))
# Person(name=Name(first='Пелагий', last='Британец', number=None, nickname=None), position=None)
# Person(name=Name(first='Аврелий', last='Августин', number=None, nickname=None), position=None)
# Person(name=Name(first='Лукиан', last=None, number=None, nickname=None), position=Position(position='пресвитер Кафар Гамалы'))
# Person(name=Name(first='Анастасий', last='Библиотекарь', number=None, nickname=None), position=None)
# Person(name=Name(first='Проспера', last=None, number=None, nickname='Аквитанского'), position=None)
# Person(name=Name(first='Пахомий', last=None, number=None, nickname='Великий'), position=None)
# Person(name=Name(first='Вигилий', last=None, number=None, nickname=None), position=Position(position='диакон'))
# Person(name=Name(first='Фастидий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Целестин', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Антонин', last='Гонорат', number=None, nickname=None), position=Position(position='епископ Константины'))
# Person(name=Name(first='Викентий', last=None, number=None, nickname='Леринский'), position=None)
# Person(name=Name(first='Евхерий', last=None, number=None, nickname='Лионский'), position=None)
# Person(name=Name(first='Иларий', last=None, number=None, nickname='Арелатский'), position=None)
# Person(name=Name(first='Марцеллин', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Валериан', last=None, number=None, nickname=None), position=Position(position='епископ Кемелийский'))
# Person(name=Name(first='Сальвиан', last=None, number=None, nickname='Массилийский'), position=None)
# Person(name=Name(first='Клавдиан', last='Мамерт', number=None, nickname=None), position=None)
# Person(name=Name(first='Патрик', last=None, number=None, nickname='Ирландский'), position=None)
# Person(name=Name(first='Урбан', last=None, number=None, nickname=None), position=Position(position='пресвитер'))
# Person(name=Name(first='Евстафий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Виктор', last=None, number=None, nickname='Витенский'), position=None)
# Person(name=Name(first='Сидоний', last='Аполлинарий', number=None, nickname=None), position=None)
# Person(name=Name(first='Цереалий', last=None, number=None, nickname='Касталланский'), position=None)
# Person(name=Name(first='Евгений', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Феликс', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Геннадий', last=None, number=None, nickname='Массилийский'), position=None)
# Person(name=Name(first='Авит', last=None, number=None, nickname='Вьеннский'), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname=None), position=Position(position='диакон'))
# Person(name=Name(first='Фаустин', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Юлиан', last='Померий', number=None, nickname=None), position=None)
# Person(name=Name(first='Павлин', last=None, number=None, nickname='Ноланский'), position=None)
# Person(name=Name(first='Клавдий', last='Марий Виктор', number=None, nickname=None), position=None)
# Person(name=Name(first='Павлин', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дрепаний', last='Флор', number=None, nickname=None), position=None)
# Person(name=Name(first='Симмах', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Пётр', last=None, number=None, nickname=None), position=Position(position='диакон'))
# Person(name=Name(first='Вигилий', last=None, number=None, nickname='Тапсский'), position=None)
# Person(name=Name(first='Афанасий', last=None, number=None, nickname='Александрийский'), position=Position(position='перевод'))
# Person(name=Name(first='Лев', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Гельпидий', last='Рустик', number=None, nickname=None), position=None)
# Person(name=Name(first='Евгиппий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Эльпида', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Феликс', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бонифаций', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иоанн', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Агапит', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Лаврентий', last=None, number=None, nickname=None), position=Position(position='епископ Новарский'))
# Person(name=Name(first='Бенедикт', last=None, number=None, nickname='Нурсианский'), position=None)
# Person(name=Name(first='Альберик', last=None, number=None, nickname=None), position=Position(position='диакон'))
# Person(name=Name(first='Узеса', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гермианы', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ферранд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Троян', last=None, number=None, nickname='Сентский'), position=None)
# Person(name=Name(first='Понтиан', last='Африканец', number=None, nickname=None), position=None)
# Person(name=Name(first='Кесарий', last=None, number=None, nickname='Арелатский'), position=None)
# Person(name=Name(first='Лев', last=None, number=None, nickname=None), position=Position(position='епископ Сансский'))
# Person(name=Name(first='Юнилий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Маппин', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Виктор', last=None, number=None, nickname=None), position=Position(position='епископ Капуи'))
# Person(name=Name(first='Агнелл', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Аврелиан', last=None, number=None, nickname='Арелатский'), position=None)
# Person(name=Name(first='Примасий', last=None, number=None, nickname=None), position=Position(position='епископ Гадруметский'))
# Person(name=Name(first='Виктор', last=None, number=None, nickname='Туннунский'), position=None)
# Person(name=Name(first='Вигилий', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Юстиниан', last=None, number='I', nickname=None), position=Position(position='император'))
# Person(name=Name(first='Гильда', last=None, number=None, nickname='Премудрый'), position=None)
# Person(name=Name(first='Пелагий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Кассиодор', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Хильдеберт', last=None, number='I', nickname=None), position=None)
# Person(name=Name(first='Эрхамберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Мартин', last=None, number=None, nickname='Бракарский'), position=None)
# Person(name=Name(first='Герман', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Радегунда', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бенедикт', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Лициниан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Веран', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Пелагий', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Аунарий', last=None, number=None, nickname='Осерский'), position=None)
# Person(name=Name(first='Марий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Лукулент', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname='Арелатский'), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname='Бикларский'), position=None)
# Person(name=Name(first='Леандр', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Антоний', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Флориан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Юстиниан', last=None, number='I', nickname=None), position=Position(position='император'))
# Person(name=Name(first='Пафнутий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Василия', last=None, number=None, nickname='Кесарийского'), position=None)
# Person(name=Name(first='Антоний', last='Дисципул', number=None, nickname=None), position=None)
# Person(name=Name(first='Леонтий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Феофил', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last='Дамаскин', number=None, nickname=None), position=None)
# Person(name=Name(first='Ефрем', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иаков', last='Диакон', number=None, nickname=None), position=None)
# Person(name=Name(first='Софроний', last=None, number=None, nickname='Иерусалимский'), position=None)
# Person(name=Name(first='Пелагия', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Лавсаик', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname='Мосх'), position=None)
# Person(name=Name(first='Гераклид', last=None, number=None, nickname='Александрийский'), position=None)
# Person(name=Name(first='Лавсаик', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Геласий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Феодорит', last=None, number=None, nickname='Кирский'), position=None)
# Person(name=Name(first='Дамасий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Григорий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Григория', last=None, number='I', nickname=None), position=None)
# Person(name=Name(first='Алульф', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Тарра', last=None, number=None, nickname=None), position=Position(position='монах'))
# Person(name=Name(first='Динам', last=None, number=None, nickname=None), position=Position(position='патрикий'))
# Person(name=Name(first='Августин', last=None, number=None, nickname='Кентерберийский'), position=None)
# Person(name=Name(first='Бонифаций', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Павел', last='Эмеритан Диакон', number=None, nickname=None), position=None)
# Person(name=Name(first='Тамай', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Марк', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Варнахарий', last=None, number=None, nickname=None), position=Position(position='епископ Лангрский'))
# Person(name=Name(first='Альфан', last=None, number=None, nickname=None), position=Position(position='епископ Беневентский'))
# Person(name=Name(first='Айлеран', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бертихрамн', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Протандий', last=None, number=None, nickname=None), position=Position(position='архиепископ Безансона'))
# Person(name=Name(first='Бонифаций', last=None, number='V', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Вер', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гонорий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Аутберт', last=None, number=None, nickname=None), position=Position(position='епископ Камбре'))
# Person(name=Name(first='Иоанн', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Максим', last=None, number=None, nickname=None), position=Position(position='епископ Сарагосы'))
# Person(name=Name(first='Евтранд', last=None, number=None, nickname=None), position=Position(position='диакон из Павии'))
# Person(name=Name(first='Виктор', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Браулио', last=None, number=None, nickname='Сарагосский'), position=None)
# Person(name=Name(first='Тайо', last=None, number=None, nickname=None), position=Position(position='епископ Сарагосы'))
# Person(name=Name(first='Галлии', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Исидор', last=None, number=None, nickname='Севильский'), position=None)
# Person(name=Name(first='Теодор', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Мавр', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Мартин', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Павел', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дезидерий', last=None, number=None, nickname=None), position=Position(position='епископ Каорский'))
# Person(name=Name(first='Донат', last=None, number=None, nickname=None), position=Position(position='епископ Безансона'))
# Person(name=Name(first='Ландерик', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Евгений', last=None, number='III', nickname=None), position=None)
# Person(name=Name(first='Валерий', last=None, number=None, nickname=None), position=Position(position='аббат'))
# Person(name=Name(first='Валерий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Аннемунд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Элигий', last=None, number=None, nickname=None), position=Position(position='епископ Нуайонский'))
# Person(name=Name(first='Маркульф', last=None, number=None, nickname=None), position=Position(position='монах'))
# Person(name=Name(first='Куммиан', last='Ирландец', number=None, nickname=None), position=None)
# Person(name=Name(first='Виталиан', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иона', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дон', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Агафон', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Дамиан', last=None, number=None, nickname=None), position=Position(position='епископ Павии'))
# Person(name=Name(first='Аманд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Троклара', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адамнан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адаман', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Сергий', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иоанн', last=None, number='VI', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иоанн', last=None, number='VII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Альдхельм', last=None, number=None, nickname=None), position=Position(position='епископ Шерборна'))
# Person(name=Name(first='Константин', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Кеолфрид', last=None, number=None, nickname=None), position=Position(position='пресвитер Уирмута'))
# Person(name=Name(first='Феликс', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бенедикт', last=None, number=None, nickname='Крисп'), position=None)
# Person(name=Name(first='Эгберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Григорий', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Григорий', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бонифаций', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Захария', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Стефан', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Киприан', last=None, number=None, nickname=None), position=Position(position='монах из Кассино'))
# Person(name=Name(first='Хродеган', last=None, number=None, nickname=None), position=Position(position='епископ Мецский'))
# Person(name=Name(first='Павел', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Стурмий', last=None, number=None, nickname=None), position=Position(position='аббат Фульды'))
# Person(name=Name(first='Амвросий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Павел', last='Диакон', number=None, nickname=None), position=None)
# Person(name=Name(first='Ландульф', last=None, number=None, nickname='Хитроумный'), position=None)
# Person(name=Name(first='Леодегарий', last=None, number=None, nickname=None), position=Position(position='епископ Отёнский'))
# Person(name=Name(first='Лев', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бенедикт', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иоанн', last=None, number='V', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Юлиан', last=None, number=None, nickname='Толедский'), position=None)
# Person(name=Name(first='Лулл', last=None, number=None, nickname='Майнцский'), position=None)
# Person(name=Name(first='Элипанд', last=None, number=None, nickname='Толедский'), position=None)
# Person(name=Name(first='Феликс', last=None, number=None, nickname='Урхельский'), position=None)
# Person(name=Name(first='Рахио', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ангильрамн', last=None, number=None, nickname='Мецский'), position=None)
# Person(name=Name(first='Адриан', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Исидор', last=None, number=None, nickname='Бежский'), position=None)
# Person(name=Name(first='Пётр', last=None, number=None, nickname=None), position=Position(position='архидиакон'))
# Person(name=Name(first='Катульф', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Карл', last=None, number=None, nickname='Великий'), position=None)
# Person(name=Name(first='Людовик', last=None, number='I', nickname='Благочестивый'), position=None)
# Person(name=Name(first='Бенедикт', last='Левит', number=None, nickname=None), position=None)
# Person(name=Name(first='Лев', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Людовик', last=None, number='I', nickname='Благочестивый'), position=None)
# Person(name=Name(first='Адриан', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Галлена', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Карла', last=None, number=None, nickname='Великого'), position=None)
# Person(name=Name(first='О', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Людгер', last=None, number=None, nickname='Мюнстерский'), position=None)
# Person(name=Name(first='Фарнульф', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дагульф', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ангильберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Лейдрад', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Амаларий', last='Фортунат', number=None, nickname=None), position=None)
# Person(name=Name(first='Теодор', last=None, number=None, nickname='Кентерберийский'), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Аскарий', last='Тусаредо', number=None, nickname=None), position=None)
# Person(name=Name(first='Людовик', last=None, number='I', nickname='Благочестивый'), position=None)
# Person(name=Name(first='Магн', last=None, number=None, nickname=None), position=Position(position='архиепископ Санса'))
# Person(name=Name(first='Лев', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Седулий', last='Скот', number=None, nickname=None), position=None)
# Person(name=Name(first='Вигилий', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бенедикт', last=None, number=None, nickname='Анианский'), position=None)
# Person(name=Name(first='Григорий', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Эйнхард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Клавдий', last=None, number=None, nickname='Туринский'), position=None)
# Person(name=Name(first='Людовик', last=None, number='I', nickname='Благочестивый'), position=None)
# Person(name=Name(first='Теодульф', last=None, number=None, nickname='Орлеанский'), position=None)
# Person(name=Name(first='Эйгиль', last=None, number=None, nickname='Фульдский'), position=None)
# Person(name=Name(first='Клермон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дунгал', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адальхард', last=None, number=None, nickname=None), position=Position(position='аббат Корвейский'))
# Person(name=Name(first='Эрмольд', last='Нигелл', number=None, nickname=None), position=None)
# Person(name=Name(first='Евгений', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Халитгарий', last=None, number=None, nickname=None), position=Position(position='епископ Камбре'))
# Person(name=Name(first='Фредегиз', last=None, number=None, nickname=None), position=Position(position='аббат'))
# Person(name=Name(first='Иеремия', last=None, number=None, nickname=None), position=Position(position='архиепископ Сансский'))
# Person(name=Name(first='Ансегис', last=None, number=None, nickname=None), position=Position(position='аббат Фонтенелля'))
# Person(name=Name(first='Фаста', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Хильдерик', last=None, number=None, nickname=None), position=Position(position='аббат Кассинский'))
# Person(name=Name(first='Алдрик', last=None, number=None, nickname=None), position=Position(position='архиепископ Сансский'))
# Person(name=Name(first='Амаларий', last=None, number=None, nickname='Мецский'), position=Position(position='Симфосий'))
# Person(name=Name(first='Иона', last=None, number=None, nickname='Орлеанский'), position=None)
# Person(name=Name(first='Хильдемар', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Теган', last=None, number=None, nickname=None), position=Position(position='хорепископ Трирский'))
# Person(name=Name(first='Агнелл', last=None, number=None, nickname='Равеннский'), position=None)
# Person(name=Name(first='Григорий', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Фротарий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ильдефонс', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иосиф', last=None, number=None, nickname=None), position=Position(position='священник'))
# Person(name=Name(first='Сергий', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Фрекульф', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Христиан', last='Друтмар', number=None, nickname=None), position=None)
# Person(name=Name(first='Аврелиан', last=None, number=None, nickname='Рекомский'), position=None)
# Person(name=Name(first='Аудрад', last=None, number=None, nickname=None), position=Position(position='хорепископ Сансский'))
# Person(name=Name(first='Лев', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бенедикт', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Евлогий', last=None, number=None, nickname='Толедский'), position=None)
# Person(name=Name(first='Эрманрик', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эрхамберт', last=None, number=None, nickname=None), position=Position(position='епископ Фрайзингский'))
# Person(name=Name(first='Нитхард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Амуло', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Хаймон', last=None, number=None, nickname='Хальберштадтский'), position=None)
# Person(name=Name(first='Ансгар', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Григорий', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Родульф', last=None, number=None, nickname=None), position=Position(position='епископ Буржский'))
# Person(name=Name(first='Орлеана', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Николай', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Ратрамн', last=None, number=None, nickname='Корбийский'), position=None)
# Person(name=Name(first='Гюнтар', last=None, number=None, nickname='Кёльнский'), position=None)
# Person(name=Name(first='Альваро', last=None, number=None, nickname='Кордовский'), position=None)
# Person(name=Name(first='Леовигильд', last=None, number=None, nickname='Кордовский'), position=None)
# Person(name=Name(first='Киприан', last=None, number=None, nickname='Кордовский'), position=None)
# Person(name=Name(first='Бернард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Вандальберт', last=None, number=None, nickname='Прюмский'), position=None)
# Person(name=Name(first='Герард', last=None, number=None, nickname=None), position=Position(position='архиепископ Турский'))
# Person(name=Name(first='Гримальд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Милон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Вулфад', last=None, number=None, nickname=None), position=Position(position='епископ Буржский'))
# Person(name=Name(first='Иоанн', last='Скот Эриугена', number=None, nickname=None), position=None)
# Person(name=Name(first='Адриан', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Узуард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адревальд', last=None, number=None, nickname=None), position=Position(position='монах Флёри'))
# Person(name=Name(first='Лана', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Исаак', last=None, number=None, nickname=None), position=Position(position='епископ Лангрский'))
# Person(name=Name(first='Бовэ', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Хейрик', last=None, number=None, nickname='Осерский'), position=None)
# Person(name=Name(first='Иоанн', last=None, number='VIII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Марин', last=None, number='I', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Адриан', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бертарий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Хармот', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Римберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Анастасий', last='Библиотекарь', number=None, nickname=None), position=None)
# Person(name=Name(first='Франциск', last='Бланхин', number=None, nickname='Веронский'), position=None)
# Person(name=Name(first='Григорий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Анастасий', last='Библиотекарь', number=None, nickname=None), position=None)
# Person(name=Name(first='Эрхемберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ангильберт', last=None, number=None, nickname=None), position=Position(position='аббат Корвейский'))
# Person(name=Name(first='Стефан', last=None, number='V', nickname=None), position=None)
# Person(name=Name(first='Стефан', last=None, number='VI', nickname=None), position=None)
# Person(name=Name(first='Роман', last=None, number=None, nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Вольфхард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Евтропий', last='Лангобард', number=None, nickname=None), position=None)
# Person(name=Name(first='Псевдо', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Исидор', last='Меркатор', number=None, nickname=None), position=None)
# Person(name=Name(first='Рикульф', last=None, number=None, nickname=None), position=Position(position='епископ Суассонский'))
# Person(name=Name(first='Манцио', last=None, number=None, nickname=None), position=Position(position='епископ Шалонский'))
# Person(name=Name(first='Иоанн', last=None, number='IX', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бенедикт', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Христофор', last=None, number=None, nickname=None), position=Position(position='антипапа'))
# Person(name=Name(first='Сергий', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Анастасий', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Бертарий', last=None, number=None, nickname='Верденский'), position=None)
# Person(name=Name(first='Роберт', last=None, number='I', nickname=None), position=Position(position='епископ Меца'))
# Person(name=Name(first='Саломон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Одилон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Стефан', last=None, number=None, nickname=None), position=Position(position='епископ Льежа'))
# Person(name=Name(first='Дадон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Агий', last=None, number=None, nickname=None), position=Position(position='архиепископ Нарбонны'))
# Person(name=Name(first='Иоанн', last=None, number='X', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Лев', last=None, number='VI', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Хукбальд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Стефан', last=None, number='VII', nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number='XI', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Сеульф', last=None, number=None, nickname=None), position=Position(position='архиепископ Реймса'))
# Person(name=Name(first='Лев', last=None, number='VII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Стефан', last=None, number='VIII', nickname=None), position=None)
# Person(name=Name(first='Леотальд', last=None, number=None, nickname='Маконский'), position=None)
# Person(name=Name(first='Клермон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Марин', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Козьма', last='Япиг', number=None, nickname='Матерский'), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname='Итал'), position=None)
# Person(name=Name(first='Лаврентий', last=None, number=None, nickname='Кассинский'), position=None)
# Person(name=Name(first='Агапит', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Одон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Артольд', last=None, number=None, nickname=None), position=Position(position='архиепископ Реймса'))
# Person(name=Name(first='Одальрик', last=None, number=None, nickname=None), position=Position(position='архиепископ Реймса'))
# Person(name=Name(first='Сигехард', last=None, number=None, nickname='Трирский'), position=None)
# Person(name=Name(first='Иоанн', last=None, number='XII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Адальгер', last=None, number=None, nickname=None), position=Position(position='епископ'))
# Person(name=Name(first='Бруно', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Лев', last=None, number='VIII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Вибольд', last=None, number=None, nickname=None), position=Position(position='епископ Камбре'))
# Person(name=Name(first='Флодоард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гумпольд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эралий', last=None, number=None, nickname=None), position=Position(position='епископ Льежский'))
# Person(name=Name(first='Иоанн', last=None, number='XIII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Ульрих', last=None, number=None, nickname=None), position=Position(position='епископ Аугсбурга'))
# Person(name=Name(first='Бенедикт', last=None, number='VI', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Рихард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адальберт', last=None, number=None, nickname='Мецский'), position=None)
# Person(name=Name(first='Хельперик', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Этельвольд', last=None, number=None, nickname='Уинчестерский'), position=None)
# Person(name=Name(first='Видукинд', last=None, number=None, nickname='Корвейский'), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бенедикт', last=None, number='VII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иоанн', last=None, number='XIV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Теодерик', last=None, number=None, nickname=None), position=Position(position='епископ Мецский'))
# Person(name=Name(first='Лоббе', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эркембальд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Аймард', last=None, number=None, nickname=None), position=Position(position='аббат Клюнийский'))
# Person(name=Name(first='Летальд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number='XV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Гвидо', last=None, number='II', nickname=None), position=None)
# Person(name=Name(first='Адальберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Григорий', last=None, number='V', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Конрад', last='Кельт', number=None, nickname=None), position=None)
# Person(name=Name(first='Хросвита', last=None, number=None, nickname='Гандерсгеймская'), position=None)
# Person(name=Name(first='Герард', last=None, number=None, nickname='Суассонский'), position=None)
# Person(name=Name(first='Теральд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Амблалард', last=None, number=None, nickname=None), position=Position(position='аббат Солиньякский'))
# Person(name=Name(first='Альфреда', last=None, number=None, nickname='Великого'), position=None)
# Person(name=Name(first='Сильвестр', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Пурхард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Тиепальд', last=None, number=None, nickname=None), position=Position(position='аббат Тегернзее'))
# Person(name=Name(first='Альберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Рорико', last=None, number=None, nickname='Муассакский'), position=None)
# Person(name=Name(first='Иоанн', last='Диакон Венецианец', number=None, nickname=None), position=None)
# Person(name=Name(first='Херигер', last=None, number=None, nickname='Лоббский'), position=None)
# Person(name=Name(first='Титмар', last=None, number=None, nickname=None), position=Position(position='епископ Мерзебургский'))
# Person(name=Name(first='Тангмар', last=None, number=None, nickname='Хильдесхаймский'), position=None)
# Person(name=Name(first='Бурхард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адельбольд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ромуальд', last=None, number=None, nickname=None), position=Position(position='аббат Камальдуленский'))
# Person(name=Name(first='Бернард', last=None, number=None, nickname='Анжерский'), position=None)
# Person(name=Name(first='Фульберт', last=None, number=None, nickname=None), position=Position(position='епископ Шартрский'))
# Person(name=Name(first='Гвидон', last=None, number=None, nickname='Аретинский'), position=None)
# Person(name=Name(first='Дудон', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гослен', last=None, number=None, nickname=None), position=Position(position='архиепископ Буржский'))
# Person(name=Name(first='Лана', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Пьер', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Мегинфрид', last=None, number=None, nickname='Магдебургский'), position=None)
# Person(name=Name(first='Арнольд', last=None, number=None, nickname='Эммерамский'), position=None)
# Person(name=Name(first='Эбал', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number='XIX', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Годехард', last=None, number=None, nickname=None), position=Position(position='епископ Хильдесхаймский'))
# Person(name=Name(first='Фроумунд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эберхард', last=None, number=None, nickname=None), position=Position(position='аббат Тегернзее'))
# Person(name=Name(first='Перингер', last=None, number=None, nickname=None), position=Position(position='аббат Тегернзее'))
# Person(name=Name(first='Эллингер', last=None, number=None, nickname=None), position=Position(position='аббат Тегернзее'))
# Person(name=Name(first='Удальрик', last=None, number=None, nickname=None), position=Position(position='аббат Тегернзее'))
# Person(name=Name(first='Отельбольд', last=None, number=None, nickname=None), position=Position(position='аббат Гента'))
# Person(name=Name(first='Бенедикт', last=None, number='IX', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Хериберт', last=None, number=None, nickname=None), position=Position(position='епископ Айхштетский'))
# Person(name=Name(first='Ангельранн', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Роберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гарсия', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Доминик', last=None, number=None, nickname=None), position=Position(position='патриарх Градо и Аквилеи'))
# Person(name=Name(first='Григорий', last=None, number='VI', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Климент', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Рауль', last='Глабер', number=None, nickname=None), position=None)
# Person(name=Name(first='Сифрид', last=None, number=None, nickname=None), position=Position(position='аббат Тегернзее'))
# Person(name=Name(first='Одоранн', last=None, number=None, nickname='Сансский'), position=None)
# Person(name=Name(first='Одилон', last=None, number=None, nickname='Клюнийский'), position=None)
# Person(name=Name(first='Герард', last=None, number=None, nickname=None), position=Position(position='епископ Камбре'))
# Person(name=Name(first='Гуго', last=None, number=None, nickname=None), position=Position(position='епископ Лангрский'))
# ...
# Person(name=Name(first='Иоанн', last=None, number=None, nickname='Михиэльский'), position=None)
# Person(name=Name(first='Гальберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бальдерик', last='Дольский', number=None, nickname=None), position=None)
# Person(name=Name(first='Гонорий', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Вивиан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гауссельм', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Аббауд', last=None, number=None, nickname=None), position=Position(position='аббат'))
# Person(name=Name(first='Бруно', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Фридерик', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Рихард', last=None, number=None, nickname=None), position=Position(position='аббат Фрателльский'))
# Person(name=Name(first='Стефан', last=None, number=None, nickname=None), position=Position(position='аббат цистерцианцев'))
# Person(name=Name(first='Иоанн', last=None, number=None, nickname=None), position=Position(position='монах'))
# Person(name=Name(first='Гуго', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Роберт', last=None, number=None, nickname=None), position=Position(position='аббат Молесма'))
# Person(name=Name(first='Германн', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Мунио', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Норберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гонорий', last=None, number=None, nickname='Отёнский'), position=None)
# Person(name=Name(first='Стефан', last=None, number=None, nickname=None), position=Position(position='епископ Отёнский'))
# Person(name=Name(first='Герард', last=None, number=None, nickname=None), position=Position(position='епископ Ангулемский'))
# Person(name=Name(first='Оддо', last=None, number=None, nickname='Реймсский'), position=None)
# Person(name=Name(first='Адальберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Райнальд', last=None, number='II', nickname=None), position=None)
# Person(name=Name(first='Ольдегарий', last=None, number=None, nickname=None), position=Position(position='архиепископ Таррагонский'))
# Person(name=Name(first='Гауффрид', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Лев', last=None, number=None, nickname='Остийский'), position=None)
# Person(name=Name(first='Пётр', last='Диакон', number=None, nickname=None), position=None)
# Person(name=Name(first='Беневента', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Матфей', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гауфрид', last=None, number=None, nickname=None), position=Position(position='епископ Шалонский'))
# Person(name=Name(first='Стефан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гуго', last=None, number=None, nickname=None), position=Position(position='архиепископ Сансский'))
# Person(name=Name(first='Ландульф', last=None, number=None, nickname='Младший'), position=None)
# Person(name=Name(first='Годефрид', last=None, number=None, nickname=None), position=Position(position='аббат Адмонта'))
# Person(name=Name(first='Лизиард', last=None, number=None, nickname=None), position=Position(position='клирик из Тура'))
# Person(name=Name(first='Иоанн', last=None, number=None, nickname='Корнуолльский'), position=None)
# Person(name=Name(first='Роберт', last='Павлул', number=None, nickname=None), position=None)
# Person(name=Name(first='Иларий', last=None, number=None, nickname=None), position=Position(position='ученик Абеляра'))
# Person(name=Name(first='Пётр', last=None, number=None, nickname='Беренгарий'), position=Position(position='ученик Абеляра'))
# Person(name=Name(first='Вулгрин', last=None, number=None, nickname=None), position=Position(position='архиепископ Буржский'))
# Person(name=Name(first='Бенедикт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number='XIX', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Целестин', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Луций', last=None, number='II', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Вильям', last=None, number=None, nickname='Мальмсберийский'), position=None)
# Person(name=Name(first='Гуго', last='Фарсит', number=None, nickname=None), position=None)
# Person(name=Name(first='Монтис', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Теульф', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname=None), position=Position(position='монах из Льежа'))
# Person(name=Name(first='Тьерри', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Альгер', last=None, number=None, nickname='Льежский'), position=None)
# Person(name=Name(first='Генрих', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Евгений', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Ульгерий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Пётр', last=None, number=None, nickname='Дижонский'), position=None)
# Person(name=Name(first='Хериберт', last=None, number=None, nickname=None), position=Position(position='монах'))
# Person(name=Name(first='Райнард', last=None, number=None, nickname=None), position=Position(position='аббат Кистекский'))
# Person(name=Name(first='Гуго', last=None, number=None, nickname=None), position=Position(position='аббат Макона и Понтиньи'))
# Person(name=Name(first='Гиллеберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гауффрид', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Николай', last=None, number=None, nickname='Клервоский'), position=None)
# Person(name=Name(first='Огерий', last=None, number=None, nickname=None), position=Position(position='аббат Лучедио'))
# Person(name=Name(first='Гверрик', last=None, number=None, nickname=None), position=Position(position='аббат Иньи'))
# Person(name=Name(first='Арнульф', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бернар', last=None, number=None, nickname='Клервоский'), position=None)
# Person(name=Name(first='Филофей', last=None, number=None, nickname=None), position=Position(position='монах'))
# Person(name=Name(first='Николай', last='Хоквилль', number=None, nickname=None), position=None)
# Person(name=Name(first='Гоффрид', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Захария', last=None, number=None, nickname=None), position=Position(position='епископ'))
# Person(name=Name(first='Роберт', last='Пулл', number=None, nickname=None), position=None)
# Person(name=Name(first='Сугерий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Дени', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ордерик', last='Виталий', number=None, nickname=None), position=None)
# Person(name=Name(first='Гверрик', last=None, number=None, nickname=None), position=Position(position='аббат Иньи'))
# Person(name=Name(first='Анастасий', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Ансельм', last=None, number=None, nickname=None), position=Position(position='епископ Хафельбергский'))
# Person(name=Name(first='Жильбер', last=None, number=None, nickname='Порретанский'), position=Position(position='епископ Пуатье'))
# Person(name=Name(first='Гуго', last='Метелл', number=None, nickname=None), position=Position(position='каноник'))
# Person(name=Name(first='Амедей', last=None, number=None, nickname=None), position=Position(position='епископ Лозаннский'))
# Person(name=Name(first='Николай', last=None, number=None, nickname='Клюнийский'), position=None)
# Person(name=Name(first='Адриан', last=None, number='IV', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Иоанн', last='Кирита', number=None, nickname=None), position=Position(position='аббат Тарауканский'))
# Person(name=Name(first='Альфонс', last=None, number='I', nickname='Португальский'), position=None)
# Person(name=Name(first='Роберт', last=None, number=None, nickname='Ретельский'), position=None)
# Person(name=Name(first='Вибальд', last=None, number=None, nickname=None), position=Position(position='аббат Ставло'))
# Person(name=Name(first='Эрнальд', last=None, number=None, nickname=None), position=Position(position='аббат Бонневалльский'))
# Person(name=Name(first='Жильбер', last='Фолио', number=None, nickname=None), position=None)
# Person(name=Name(first='Герберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Алан', last=None, number=None, nickname=None), position=Position(position='аббат Тьюксбери'))
# Person(name=Name(first='Бандин', last=None, number=None, nickname=None), position=Position(position='магистр'))
# Person(name=Name(first='Гуго', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Арно', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last='Диакон', number=None, nickname=None), position=None)
# Person(name=Name(first='Гуго', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Исаак', last='Стелла', number=None, nickname=None), position=Position(position='аббат цистерцианцев'))
# Person(name=Name(first='Генрих', last=None, number=None, nickname='Хантингдонский'), position=None)
# Person(name=Name(first='Рихард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Ахард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эрвизий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гварин', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Годфрид', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Адам', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Иосцелин', last=None, number=None, nickname=None), position=Position(position='епископ Турский'))
# Person(name=Name(first='Генрих', last=None, number=None, nickname='Зальцбургский'), position=None)
# Person(name=Name(first='Генрих', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гуго', last=None, number=None, nickname=None), position=Position(position='епископ Суассонский'))
# Person(name=Name(first='Николай', last=None, number=None, nickname=None), position=Position(position='монах Арематский'))
# Person(name=Name(first='Годфрид', last=None, number=None, nickname='Витербский'), position=None)
# Person(name=Name(first='Пётр', last='Коместор', number=None, nickname=None), position=None)
# Person(name=Name(first='Иоанн', last=None, number=None, nickname='Корнуолльский'), position=None)
# Person(name=Name(first='Гвихард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Пётр', last=None, number=None, nickname=None), position=Position(position='кардинал'))
# Person(name=Name(first='Александр', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Луций', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Алан', last=None, number=None, nickname='Осерский'), position=None)
# Person(name=Name(first='Пётр', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эмерик', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гуго', last='Этериан', number=None, nickname=None), position=None)
# Person(name=Name(first='Пётр', last=None, number=None, nickname=None), position=Position(position='епископ Шартрский'))
# Person(name=Name(first='Жильбер', last='Фолио', number=None, nickname=None), position=None)
# Person(name=Name(first='Роберт', last=None, number=None, nickname=None), position=Position(position='аббат Ториннейо'))
# Person(name=Name(first='Урбан', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Григорий', last=None, number='VIII', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Генрих', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бонакурс', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Бернард', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Генрих', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Лаврентий', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Стефан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Стефан', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Пётр', last='Бернард', number=None, nickname=None), position=None)
# Person(name=Name(first='Герард', last='Итерий', number=None, nickname=None), position=None)
# Person(name=Name(first='Дандина', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эрменгауд', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Климент', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Сюлли', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Александр', last=None, number=None, nickname=None), position=Position(position='аббат Жюмьежский'))
# Person(name=Name(first='Геральд', last=None, number=None, nickname=None), position=Position(position='епископ Каорский'))
# Person(name=Name(first='Матфей', last=None, number=None, nickname='Вандомский'), position=None)
# Person(name=Name(first='Целестин', last=None, number='III', nickname=None), position=Position(position='папа римский'))
# Person(name=Name(first='Вальтер', last=None, number=None, nickname='Шатильонский'), position=None)
# Person(name=Name(first='Вильгельм', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Абсалон', last=None, number=None, nickname=None), position=Position(position='архиепископ Лундский'))
# Person(name=Name(first='Иоанн', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гуго', last=None, number='V', nickname=None), position=Position(position='аббат Клюни'))
# Person(name=Name(first='Ростан', last=None, number=None, nickname='Клюнийский'), position=None)
# Person(name=Name(first='Элиас', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Томас', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Стефан', last=None, number=None, nickname=None), position=Position(position='епископ Турне'))
# Person(name=Name(first='Адам', last=None, number=None, nickname=None), position=Position(position='аббат Персеньский'))
# Person(name=Name(first='Пётр', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Гвиберт', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Эгидий', last=None, number=None, nickname='Парижский'), position=None)
# Person(name=Name(first='Сюлли', last=None, number=None, nickname=None), position=None)
# Person(name=Name(first='Хелинанд', last=None, number=None, nickname='Фруадмонский'), position=None)
# Person(name=Name(first='Пётр', last=None, number=None, nickname=None), position=None)

# %%
titled_books_fact = fact(
    'Book',
    ['title']
)

titled_books_rule = rule(
    '«',
    custom(lambda s: s != '»').repeatable().interpretation(titled_books_fact.title),
    '»'
).interpretation(titled_books_fact)

titled_books_parser = Parser(titled_books_rule)

# %%
# Books
for sent in doc.sents:
    parsed = titled_books_parser.find(sent.text)
    if parsed:
        print(parsed.fact)
# Out:
# Book(title='Полного курса патрологии')
# Book(title='Мученичество святых Перпетуи и Фелицитаты')
# Book(title='Книга происхождения от Адама')
# Book(title='Трактат к еретикам новацианам')
# Book(title='Песнь против язычников')
# Book(title='Песнь во славу Господа')
# Book(title='Хроника')
# Book(title='Шестоднева')
# Book(title='Хронологический указатель о преследованиях вандалов')
# Book(title='О франкских законах')
# Book(title='Предисловие к житию св. Павла')
# Book(title='Житие св. Онуфрия')
# Book(title='Житие св. Василия Кесарийского')
# Book(title='Житие св. Симеона Стилита')
# Book(title='Житие св. Иоанна Милостивого')
# Book(title='Житие св. Макария Римского')
# Book(title='Житие св. Варлаама и Иоасафа')
# Book(title='Житие св. Марии Блудницы')
# Book(title='Житие св. Пелагии Блудницы')
# Book(title='Житие св. Марии Египетской блудницы')
# Book(title='Verba Seniorum')
# Book(title='Паломничество')
# Book(title='Духовный луг')
# Book(title='Парадиз')
# Book(title='Лавсаик')
# Book(title='Хроника')
# Book(title='Феофил')
# Book(title='Житие св. Григория')
# Book(title='Хронология готских королей')
# Book(title='Мозарабская литургия')
# Book(title='О времени')
# Book(title='Житие испанских аббатов')
# Book(title='Исидор Бежский')
# Book(title='Деяния франкских королей')
# Book(title='Собрание капитуляриев')
# Book(title='О деяниях блаженного Карла Великого')
# Book(title='Старые франкские анналы')
# Book(title='О деяниях Карла Великого')
# Book(title='Книга римских понтификов')
# Book(title='Деяния Алдрика, епископа Ле-Мана')
# Book(title='Книга о римских понтификах')
# Book(title='Собрание декретов')
# Book(title='Церковные законы')
# Book(title='Chronicon Petrishuensis')
# Book(title='Деяния святых мучеников Арнальда и Герлембальда')
# Book(title='Фекамская хроника')
# Book(title='Деяния понтификов Камбре')
# Book(title='Хроника аббатов Бека')
# Book(title='Панегирик императору Беренгарию')
# Book(title='Трирские деяния')
# Book(title='Из истории трирских мучеников')
# Book(title='Хроника св. Губерта Арденнского')
# Book(title='Деяния епископов Меца')
# Book(title='История французских королей из монастыря Сен-Дени')
# Book(title='Древние ритмы')
# Book(title='Клервоская хроника')
# Book(title='Хроника св. Михаэля в опасном море')
# Book(title='Анналы св. Витона Верденского')

# %%
period_fact = fact(
    'Period',
    ['date_from', 'date_to']
)

period_rule = rule(
    YEAR.interpretation(period_fact.date_from),
    '—',
    YEAR.interpretation(period_fact.date_to)
).interpretation(period_fact)

period_parser = Parser(period_rule)

# %%
# Date periods
for sent in doc.sents:
    parsed = period_parser.find(sent.text)
    if parsed:
        print(parsed.fact)
# Out:
# Period(date_from=1844, date_to=1855)
# Period(date_from=1220, date_to=1246)
# Period(date_from=1091, date_to=1179)
# Period(date_from=1034, date_to=1467)
# Period(date_from=1147, date_to=1192)
